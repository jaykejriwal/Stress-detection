# %%
import glob
import shutil
import os
from pydub import AudioSegment
from colorama import Fore, Back, Style


conf_file =r'C:\Opensmile\opensmile-3.0-win-x64\config\plp\PLP_0_D_Anewxx.conf' 
audio_path=r'D:\wav\*.wav'
cvs_file=r'D:\plpfeatures.csv'
path=r'C:\Opensmile\opensmile-3.0-win-x64\bin'


if os.path.exists(cvs_file):
    print(Fore.BLUE+"Deleteing old cvs file") ,print(Style.RESET_ALL)
    os.remove(cvs_file)


for file in glob.iglob (audio_path):
    print(Fore.MAGENTA+"Exracting features from", file),print(Style.RESET_ALL)
    try:
        audio = AudioSegment.from_wav(file)
        audio.export(file,format="wav")
        cmd = path + "./SMILExtract " + " -C " + conf_file +" -I " + file +" -O " +cvs_file
        os.system(cmd)
    except : print (Fore.YELLOW+ file," is empty !") ,print(Style.RESET_ALL) 
        
print("Done")
# Out:
# Exracting features from D:\wav\s01a_10a_crisis_1_0265.wav
#
# Exracting features from D:\wav\s01a_10a_crisis_1_0266.wav
#
# Exracting features from D:\wav\s01a_10a_crisis_1_0267.wav
#
# Exracting features from D:\wav\s01a_10a_crisis_1_0268.wav
#
# Exracting features from D:\wav\s01a_10a_crisis_1_0269.wav
#
# Exracting features from D:\wav\s01a_10a_crisis_1_0270.wav
#
# Exracting features from D:\wav\s01a_10a_crisis_1_0271.wav
#
# Exracting features from D:\wav\s01a_10a_crisis_1_0272.wav
#
# Exracting features from D:\wav\s01a_10a_crisis_1_0273.wav
#
# Exracting features from D:\wav\s01a_10a_crisis_1_0274.wav
#
# Exracting features from D:\wav\s01a_10a_crisis_1_0275.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0276.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0277.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0278.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0279.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0280.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0281.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0282.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0283.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0284.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0285.wav
#
# Exracting features from D:\wav\s01a_10b_crisis_2_0286.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0287.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0288.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0289.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0290.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0291.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0292.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0293.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0294.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0295.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0296.wav
#
# Exracting features from D:\wav\s01a_10c_crisis_3_0297.wav
#
# Exracting features from D:\wav\s01a_11a_crisis_1_0298.wav
#
# Exracting features from D:\wav\s01a_11a_crisis_1_0299.wav
#
# Exracting features from D:\wav\s01a_11a_crisis_1_0300.wav
#
# Exracting features from D:\wav\s01a_11a_crisis_1_0301.wav
#
# Exracting features from D:\wav\s01a_11a_crisis_1_0302.wav
#
# Exracting features from D:\wav\s01a_11a_crisis_1_0303.wav
#
# Exracting features from D:\wav\s01a_11a_crisis_1_0304.wav
#
# Exracting features from D:\wav\s01a_11a_crisis_1_0305.wav
#
# Exracting features from D:\wav\s01a_11a_crisis_1_0306.wav
#
# Exracting features from D:\wav\s01a_11a_crisis_1_0307.wav
#
# Exracting features from D:\wav\s01a_1a_crisis_1_0001.wav
#
# Exracting features from D:\wav\s01a_1a_crisis_1_0002.wav
#
# Exracting features from D:\wav\s01a_1a_crisis_1_0003.wav
#
# Exracting features from D:\wav\s01a_1a_crisis_1_0004.wav
#
# Exracting features from D:\wav\s01a_1a_crisis_1_0005.wav
#
# Exracting features from D:\wav\s01a_1b_crisis_2_0006.wav
#
# Exracting features from D:\wav\s01a_1b_crisis_2_0007.wav
#
# Exracting features from D:\wav\s01a_1b_crisis_2_0008.wav
#
# Exracting features from D:\wav\s01a_1b_crisis_2_0009.wav
#
# Exracting features from D:\wav\s01a_1b_crisis_2_0010.wav
#
# Exracting features from D:\wav\s01a_1c_crisis_3_0011.wav
#
# Exracting features from D:\wav\s01a_1c_crisis_3_0012.wav
#
# Exracting features from D:\wav\s01a_1c_crisis_3_0013.wav
#
# Exracting features from D:\wav\s01a_1c_crisis_3_0014.wav
#
# Exracting features from D:\wav\s01a_1c_crisis_3_0015.wav
#
# Exracting features from D:\wav\s01a_2a_crisis_1_0016.wav
#
# Exracting features from D:\wav\s01a_2a_crisis_1_0017.wav
#
# Exracting features from D:\wav\s01a_2a_crisis_1_0018.wav
#
# Exracting features from D:\wav\s01a_2a_crisis_1_0019.wav
#
# Exracting features from D:\wav\s01a_2a_crisis_1_0020.wav
#
# Exracting features from D:\wav\s01a_2a_crisis_1_0021.wav
#
# Exracting features from D:\wav\s01a_2a_crisis_1_0022.wav
#
# Exracting features from D:\wav\s01a_2a_crisis_1_0023.wav
#
# Exracting features from D:\wav\s01a_2a_crisis_1_0024.wav
#
# Exracting features from D:\wav\s01a_2a_crisis_1_0025.wav
#
# Exracting features from D:\wav\s01a_2b_crisis_2_0026.wav
#
# Exracting features from D:\wav\s01a_2b_crisis_2_0027.wav
#
# Exracting features from D:\wav\s01a_2b_crisis_2_0028.wav
#
# Exracting features from D:\wav\s01a_2b_crisis_2_0029.wav
#
# Exracting features from D:\wav\s01a_2b_crisis_2_0030.wav
#
# Exracting features from D:\wav\s01a_2b_crisis_2_0031.wav
#
# Exracting features from D:\wav\s01a_2b_crisis_2_0032.wav
#
# Exracting features from D:\wav\s01a_2b_crisis_2_0033.wav
#
# Exracting features from D:\wav\s01a_2b_crisis_2_0034.wav
#
# Exracting features from D:\wav\s01a_2b_crisis_2_0035.wav
#
# Exracting features from D:\wav\s01a_2c_crisis_3_0036.wav
#
# Exracting features from D:\wav\s01a_2c_crisis_3_0037.wav
#
# Exracting features from D:\wav\s01a_2c_crisis_3_0038.wav
#
# Exracting features from D:\wav\s01a_2c_crisis_3_0039.wav
#
# Exracting features from D:\wav\s01a_2c_crisis_3_0040.wav
#
# Exracting features from D:\wav\s01a_2c_crisis_3_0041.wav
#
# Exracting features from D:\wav\s01a_2c_crisis_3_0042.wav
#
# Exracting features from D:\wav\s01a_2c_crisis_3_0043.wav
#
# Exracting features from D:\wav\s01a_2c_crisis_3_0044.wav
#
# Exracting features from D:\wav\s01a_2c_crisis_3_0045.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0046.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0047.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0048.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0049.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0050.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0051.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0052.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0053.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0054.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0055.wav
#
# Exracting features from D:\wav\s01a_3a_crisis_1_0056.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0057.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0058.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0059.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0060.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0061.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0062.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0063.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0064.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0065.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0066.wav
#
# Exracting features from D:\wav\s01a_3b_crisis_2_0067.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0068.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0069.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0070.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0071.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0072.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0073.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0074.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0075.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0076.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0077.wav
#
# Exracting features from D:\wav\s01a_3c_crisis_3_0078.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0079.wav
# Exracting features from D:\wav\s01a_4a_crisis_1_0080.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0081.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0082.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0083.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0084.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0085.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0086.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0087.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0088.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0089.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0090.wav
#
# Exracting features from D:\wav\s01a_4a_crisis_1_0091.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0092.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0093.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0094.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0095.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0096.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0097.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0098.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0099.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0100.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0101.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0102.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0103.wav
#
# Exracting features from D:\wav\s01a_4b_crisis_2_0104.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0105.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0106.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0107.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0108.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0109.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0110.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0111.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0112.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0113.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0114.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0115.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0116.wav
#
# Exracting features from D:\wav\s01a_4c_crisis_3_0117.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0118.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0119.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0120.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0121.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0122.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0123.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0124.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0125.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0126.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0127.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0128.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0129.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0130.wav
#
# Exracting features from D:\wav\s01a_5a_crisis_1_0131.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0132.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0133.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0134.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0135.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0136.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0137.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0138.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0139.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0140.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0141.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0142.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0143.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0144.wav
#
# Exracting features from D:\wav\s01a_5b_crisis_2_0145.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0146.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0147.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0148.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0149.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0150.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0151.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0152.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0153.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0154.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0155.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0156.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0157.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0158.wav
#
# Exracting features from D:\wav\s01a_5c_crisis_3_0159.wav
#
# Exracting features from D:\wav\s01a_6a_crisis_1_0160.wav
#
# Exracting features from D:\wav\s01a_6a_crisis_1_0161.wav
#
# Exracting features from D:\wav\s01a_6a_crisis_1_0162.wav
#
# Exracting features from D:\wav\s01a_6a_crisis_1_0163.wav
#
# Exracting features from D:\wav\s01a_6a_crisis_1_0164.wav
#
# Exracting features from D:\wav\s01a_6a_crisis_1_0165.wav
#
# Exracting features from D:\wav\s01a_6a_crisis_1_0166.wav
#
# Exracting features from D:\wav\s01a_6a_crisis_1_0167.wav
#
# Exracting features from D:\wav\s01a_6b_crisis_2_0168.wav
#
# Exracting features from D:\wav\s01a_6b_crisis_2_0169.wav
#
# Exracting features from D:\wav\s01a_6b_crisis_2_0170.wav
#
# Exracting features from D:\wav\s01a_6b_crisis_2_0171.wav
#
# Exracting features from D:\wav\s01a_6b_crisis_2_0172.wav
#
# Exracting features from D:\wav\s01a_6b_crisis_2_0173.wav
#
# Exracting features from D:\wav\s01a_6b_crisis_2_0174.wav
#
# Exracting features from D:\wav\s01a_6b_crisis_2_0175.wav
#
# Exracting features from D:\wav\s01a_6c_crisis_3_0176.wav
#
# Exracting features from D:\wav\s01a_6c_crisis_3_0177.wav
#
# Exracting features from D:\wav\s01a_6c_crisis_3_0178.wav
#
# Exracting features from D:\wav\s01a_6c_crisis_3_0179.wav
#
# Exracting features from D:\wav\s01a_6c_crisis_3_0180.wav
#
# Exracting features from D:\wav\s01a_6c_crisis_3_0181.wav
#
# Exracting features from D:\wav\s01a_6c_crisis_3_0182.wav
#
# Exracting features from D:\wav\s01a_6c_crisis_3_0183.wav
#
# Exracting features from D:\wav\s01a_7a_crisis_1_0184.wav
#
# Exracting features from D:\wav\s01a_7a_crisis_1_0185.wav
#
# Exracting features from D:\wav\s01a_7a_crisis_1_0186.wav
#
# Exracting features from D:\wav\s01a_7a_crisis_1_0187.wav
#
# Exracting features from D:\wav\s01a_7a_crisis_1_0188.wav
#
# Exracting features from D:\wav\s01a_7b_crisis_2_0189.wav
#
# Exracting features from D:\wav\s01a_7b_crisis_2_0190.wav
#
# Exracting features from D:\wav\s01a_7b_crisis_2_0191.wav
#
# Exracting features from D:\wav\s01a_7b_crisis_2_0192.wav
#
# Exracting features from D:\wav\s01a_7b_crisis_2_0193.wav
#
# Exracting features from D:\wav\s01a_7c_crisis_3_0194.wav
#
# Exracting features from D:\wav\s01a_7c_crisis_3_0195.wav
#
# Exracting features from D:\wav\s01a_7c_crisis_3_0196.wav
#
# Exracting features from D:\wav\s01a_7c_crisis_3_0197.wav
#
# Exracting features from D:\wav\s01a_7c_crisis_3_0198.wav
#
# Exracting features from D:\wav\s01a_8a_crisis_1_0199.wav
#
# Exracting features from D:\wav\s01a_8a_crisis_1_0200.wav
#
# Exracting features from D:\wav\s01a_8a_crisis_1_0201.wav
#
# Exracting features from D:\wav\s01a_8a_crisis_1_0202.wav
# Exracting features from D:\wav\s01a_8a_crisis_1_0203.wav
#
# Exracting features from D:\wav\s01a_8a_crisis_1_0204.wav
#
# Exracting features from D:\wav\s01a_8a_crisis_1_0205.wav
#
# Exracting features from D:\wav\s01a_8a_crisis_1_0206.wav
#
# Exracting features from D:\wav\s01a_8a_crisis_1_0207.wav
#
# Exracting features from D:\wav\s01a_8a_crisis_1_0208.wav
#
# Exracting features from D:\wav\s01a_8b_crisis_2_0209.wav
#
# Exracting features from D:\wav\s01a_8b_crisis_2_0210.wav
#
# Exracting features from D:\wav\s01a_8b_crisis_2_0211.wav
#
# Exracting features from D:\wav\s01a_8b_crisis_2_0212.wav
#
# Exracting features from D:\wav\s01a_8b_crisis_2_0213.wav
#
# Exracting features from D:\wav\s01a_8b_crisis_2_0214.wav
#
# Exracting features from D:\wav\s01a_8b_crisis_2_0215.wav
#
# Exracting features from D:\wav\s01a_8b_crisis_2_0216.wav
#
# Exracting features from D:\wav\s01a_8b_crisis_2_0217.wav
#
# Exracting features from D:\wav\s01a_8b_crisis_2_0218.wav
#
# Exracting features from D:\wav\s01a_8c_crisis_3_0219.wav
#
# Exracting features from D:\wav\s01a_8c_crisis_3_0220.wav
#
# Exracting features from D:\wav\s01a_8c_crisis_3_0221.wav
#
# Exracting features from D:\wav\s01a_8c_crisis_3_0222.wav
#
# Exracting features from D:\wav\s01a_8c_crisis_3_0223.wav
#
# Exracting features from D:\wav\s01a_8c_crisis_3_0224.wav
#
# Exracting features from D:\wav\s01a_8c_crisis_3_0225.wav
#
# Exracting features from D:\wav\s01a_8c_crisis_3_0226.wav
#
# Exracting features from D:\wav\s01a_8c_crisis_3_0227.wav
#
# Exracting features from D:\wav\s01a_8c_crisis_3_0228.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0229.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0230.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0231.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0232.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0233.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0234.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0235.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0236.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0237.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0238.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0239.wav
#
# Exracting features from D:\wav\s01a_9a_crisis_1_0240.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0241.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0242.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0243.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0244.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0245.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0246.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0247.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0248.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0249.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0250.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0251.wav
#
# Exracting features from D:\wav\s01a_9b_crisis_2_0252.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0253.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0254.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0255.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0256.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0257.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0258.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0259.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0260.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0261.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0262.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0263.wav
#
# Exracting features from D:\wav\s01a_9c_crisis_3_0264.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0034.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0035.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0036.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0037.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0038.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0039.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0040.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0041.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0042.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0043.wav
#
# Exracting features from D:\wav\s02a_10a_crisis_1_0044.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0045.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0046.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0047.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0048.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0049.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0050.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0051.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0052.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0053.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0054.wav
#
# Exracting features from D:\wav\s02a_10b_crisis_2_0055.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0056.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0057.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0058.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0059.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0060.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0061.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0062.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0063.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0064.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0065.wav
#
# Exracting features from D:\wav\s02a_10c_crisis_3_0066.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0067.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0068.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0069.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0070.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0071.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0072.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0073.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0074.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0075.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0076.wav
#
# Exracting features from D:\wav\s02a_11a_crisis_1_0077.wav
#
# Exracting features from D:\wav\s02a_12a_crisis_1_0078.wav
#
# Exracting features from D:\wav\s02a_12a_crisis_1_0079.wav
#
# Exracting features from D:\wav\s02a_12a_crisis_1_0080.wav
#
# Exracting features from D:\wav\s02a_12a_crisis_1_0081.wav
#
# Exracting features from D:\wav\s02a_12a_crisis_1_0082.wav
#
# Exracting features from D:\wav\s02a_12a_crisis_1_0083.wav
#
# Exracting features from D:\wav\s02a_12a_crisis_1_0084.wav
#
# Exracting features from D:\wav\s02a_12a_crisis_1_0085.wav
#
# Exracting features from D:\wav\s02a_12a_crisis_1_0086.wav
#
# Exracting features from D:\wav\s02a_12a_crisis_1_0087.wav
#
# Exracting features from D:\wav\s02a_1a_crisis_1_0001.wav
#
# Exracting features from D:\wav\s02a_1a_crisis_1_0002.wav
#
# Exracting features from D:\wav\s02a_1a_crisis_1_0003.wav
#
# Exracting features from D:\wav\s02a_1a_crisis_1_0004.wav
#
# Exracting features from D:\wav\s02a_1a_crisis_1_0005.wav
#
# Exracting features from D:\wav\s02a_1a_crisis_1_0006.wav
# Exracting features from D:\wav\s02a_1a_crisis_1_0007.wav
#
# Exracting features from D:\wav\s02a_1a_crisis_1_0008.wav
#
# Exracting features from D:\wav\s02a_1a_crisis_1_0009.wav
#
# Exracting features from D:\wav\s02a_1a_crisis_1_0010.wav
#
# Exracting features from D:\wav\s02a_1a_crisis_1_0011.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0012.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0013.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0014.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0015.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0016.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0017.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0018.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0019.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0020.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0021.wav
#
# Exracting features from D:\wav\s02a_1b_crisis_2_0022.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0023.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0024.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0025.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0026.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0027.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0028.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0029.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0030.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0031.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0032.wav
#
# Exracting features from D:\wav\s02a_1c_crisis_3_0033.wav
#
# Exracting features from D:\wav\s02a_2a_crisis_1_0088.wav
#
# Exracting features from D:\wav\s02a_2a_crisis_1_0089.wav
#
# Exracting features from D:\wav\s02a_2a_crisis_1_0090.wav
#
# Exracting features from D:\wav\s02a_2a_crisis_1_0091.wav
#
# Exracting features from D:\wav\s02a_2a_crisis_1_0092.wav
#
# Exracting features from D:\wav\s02a_2a_crisis_1_0093.wav
#
# Exracting features from D:\wav\s02a_2a_crisis_1_0094.wav
#
# Exracting features from D:\wav\s02a_2a_crisis_1_0095.wav
#
# Exracting features from D:\wav\s02a_2a_crisis_1_0096.wav
#
# Exracting features from D:\wav\s02a_2a_crisis_1_0097.wav
#
# Exracting features from D:\wav\s02a_2b_crisis_2_0098.wav
#
# Exracting features from D:\wav\s02a_2b_crisis_2_0099.wav
#
# Exracting features from D:\wav\s02a_2b_crisis_2_0100.wav
#
# Exracting features from D:\wav\s02a_2b_crisis_2_0101.wav
#
# Exracting features from D:\wav\s02a_2b_crisis_2_0102.wav
#
# Exracting features from D:\wav\s02a_2b_crisis_2_0103.wav
#
# Exracting features from D:\wav\s02a_2b_crisis_2_0104.wav
#
# Exracting features from D:\wav\s02a_2b_crisis_2_0105.wav
#
# Exracting features from D:\wav\s02a_2b_crisis_2_0106.wav
#
# Exracting features from D:\wav\s02a_2b_crisis_2_0107.wav
#
# Exracting features from D:\wav\s02a_2c_crisis_3_0108.wav
#
# Exracting features from D:\wav\s02a_2c_crisis_3_0109.wav
#
# Exracting features from D:\wav\s02a_2c_crisis_3_0110.wav
#
# Exracting features from D:\wav\s02a_2c_crisis_3_0111.wav
#
# Exracting features from D:\wav\s02a_2c_crisis_3_0112.wav
#
# Exracting features from D:\wav\s02a_2c_crisis_3_0113.wav
#
# Exracting features from D:\wav\s02a_2c_crisis_3_0114.wav
#
# Exracting features from D:\wav\s02a_2c_crisis_3_0115.wav
#
# Exracting features from D:\wav\s02a_2c_crisis_3_0116.wav
#
# Exracting features from D:\wav\s02a_2c_crisis_3_0117.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0118.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0119.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0120.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0121.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0122.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0123.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0124.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0125.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0126.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0127.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0128.wav
#
# Exracting features from D:\wav\s02a_3a_crisis_1_0129.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0130.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0131.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0132.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0133.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0134.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0135.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0136.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0137.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0138.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0139.wav
#
# Exracting features from D:\wav\s02a_3b_crisis_2_0140.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0141.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0142.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0143.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0144.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0145.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0146.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0147.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0148.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0149.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0150.wav
#
# Exracting features from D:\wav\s02a_3c_crisis_3_0151.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0152.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0153.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0154.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0155.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0156.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0157.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0158.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0159.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0160.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0161.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0162.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0163.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0164.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0165.wav
#
# Exracting features from D:\wav\s02a_4a_crisis_1_0166.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0167.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0168.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0169.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0170.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0171.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0172.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0173.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0174.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0175.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0176.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0177.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0178.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0179.wav
#
# Exracting features from D:\wav\s02a_4b_crisis_2_0180.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0181.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0182.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0183.wav
# Exracting features from D:\wav\s02a_4c_crisis_3_0184.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0185.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0186.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0187.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0188.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0189.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0190.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0191.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0192.wav
#
# Exracting features from D:\wav\s02a_4c_crisis_3_0193.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0194.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0195.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0196.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0197.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0198.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0199.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0200.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0201.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0202.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0203.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0204.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0205.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0206.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0207.wav
#
# Exracting features from D:\wav\s02a_5a_crisis_1_0208.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0209.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0210.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0211.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0212.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0213.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0214.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0215.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0216.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0217.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0218.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0219.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0220.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0221.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0222.wav
#
# Exracting features from D:\wav\s02a_5b_crisis_2_0223.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0224.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0225.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0226.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0227.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0228.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0229.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0230.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0231.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0232.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0233.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0234.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0235.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0236.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0237.wav
#
# Exracting features from D:\wav\s02a_5c_crisis_3_0238.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0239.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0240.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0241.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0242.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0243.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0244.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0245.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0246.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0247.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0248.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0249.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0250.wav
#
# Exracting features from D:\wav\s02a_6a_crisis_1_0251.wav
#
# Exracting features from D:\wav\s02a_6b_crisis_2_0252.wav
#
# Exracting features from D:\wav\s02a_6b_crisis_2_0253.wav
#
# Exracting features from D:\wav\s02a_6b_crisis_2_0254.wav
#
# Exracting features from D:\wav\s02a_6b_crisis_2_0255.wav
#
# Exracting features from D:\wav\s02a_6b_crisis_2_0256.wav
#
# Exracting features from D:\wav\s02a_6b_crisis_2_0257.wav
#
# Exracting features from D:\wav\s02a_6b_crisis_2_0258.wav
#
# Exracting features from D:\wav\s02a_6b_crisis_2_0259.wav
#
# Exracting features from D:\wav\s02a_6b_crisis_2_0260.wav
#
# Exracting features from D:\wav\s02a_6b_crisis_2_0261.wav
#
# Exracting features from D:\wav\s02a_6c_crisis_3_0262.wav
#
# Exracting features from D:\wav\s02a_6c_crisis_3_0263.wav
#
# Exracting features from D:\wav\s02a_6c_crisis_3_0264.wav
#
# Exracting features from D:\wav\s02a_6c_crisis_3_0265.wav
#
# Exracting features from D:\wav\s02a_6c_crisis_3_0266.wav
#
# Exracting features from D:\wav\s02a_6c_crisis_3_0267.wav
#
# Exracting features from D:\wav\s02a_6c_crisis_3_0268.wav
#
# Exracting features from D:\wav\s02a_6c_crisis_3_0269.wav
#
# Exracting features from D:\wav\s02a_6c_crisis_3_0270.wav
#
# Exracting features from D:\wav\s02a_7a_crisis_1_0271.wav
#
# Exracting features from D:\wav\s02a_7a_crisis_1_0272.wav
#
# Exracting features from D:\wav\s02a_7a_crisis_1_0273.wav
#
# Exracting features from D:\wav\s02a_7a_crisis_1_0274.wav
#
# Exracting features from D:\wav\s02a_7a_crisis_1_0275.wav
#
# Exracting features from D:\wav\s02a_7a_crisis_1_0276.wav
#
# Exracting features from D:\wav\s02a_7a_crisis_1_0277.wav
#
# Exracting features from D:\wav\s02a_7a_crisis_1_0278.wav
#
# Exracting features from D:\wav\s02a_7a_crisis_1_0279.wav
#
# Exracting features from D:\wav\s02a_7a_crisis_1_0280.wav
#
# Exracting features from D:\wav\s02a_7b_crisis_2_0281.wav
#
# Exracting features from D:\wav\s02a_7b_crisis_2_0282.wav
#
# Exracting features from D:\wav\s02a_7b_crisis_2_0283.wav
#
# Exracting features from D:\wav\s02a_7b_crisis_2_0284.wav
#
# Exracting features from D:\wav\s02a_7b_crisis_2_0285.wav
#
# Exracting features from D:\wav\s02a_7b_crisis_2_0286.wav
#
# Exracting features from D:\wav\s02a_7b_crisis_2_0287.wav
#
# Exracting features from D:\wav\s02a_7b_crisis_2_0288.wav
#
# Exracting features from D:\wav\s02a_7b_crisis_2_0289.wav
#
# Exracting features from D:\wav\s02a_7c_crisis_3_0290.wav
#
# Exracting features from D:\wav\s02a_7c_crisis_3_0291.wav
#
# Exracting features from D:\wav\s02a_7c_crisis_3_0292.wav
#
# Exracting features from D:\wav\s02a_7c_crisis_3_0293.wav
#
# Exracting features from D:\wav\s02a_7c_crisis_3_0294.wav
#
# Exracting features from D:\wav\s02a_7c_crisis_3_0295.wav
#
# Exracting features from D:\wav\s02a_7c_crisis_3_0296.wav
#
# Exracting features from D:\wav\s02a_7c_crisis_3_0297.wav
#
# Exracting features from D:\wav\s02a_7c_crisis_3_0298.wav
#
# Exracting features from D:\wav\s02a_7c_crisis_3_0299.wav
#
# Exracting features from D:\wav\s02a_8a_crisis_1_0300.wav
#
# Exracting features from D:\wav\s02a_8a_crisis_1_0301.wav
#
# Exracting features from D:\wav\s02a_8a_crisis_1_0302.wav
#
# Exracting features from D:\wav\s02a_8a_crisis_1_0303.wav
#
# Exracting features from D:\wav\s02a_8a_crisis_1_0304.wav
#
# Exracting features from D:\wav\s02a_8a_crisis_1_0305.wav
#
# Exracting features from D:\wav\s02a_8a_crisis_1_0306.wav
# Exracting features from D:\wav\s02a_8a_crisis_1_0307.wav
#
# Exracting features from D:\wav\s02a_8a_crisis_1_0308.wav
#
# Exracting features from D:\wav\s02a_8a_crisis_1_0309.wav
#
# Exracting features from D:\wav\s02a_8b_crisis_2_0310.wav
#
# Exracting features from D:\wav\s02a_8b_crisis_2_0311.wav
#
# Exracting features from D:\wav\s02a_8b_crisis_2_0312.wav
#
# Exracting features from D:\wav\s02a_8b_crisis_2_0313.wav
#
# Exracting features from D:\wav\s02a_8b_crisis_2_0314.wav
#
# Exracting features from D:\wav\s02a_8b_crisis_2_0315.wav
#
# Exracting features from D:\wav\s02a_8b_crisis_2_0316.wav
#
# Exracting features from D:\wav\s02a_8b_crisis_2_0317.wav
#
# Exracting features from D:\wav\s02a_8b_crisis_2_0318.wav
#
# Exracting features from D:\wav\s02a_8b_crisis_2_0319.wav
#
# Exracting features from D:\wav\s02a_8c_crisis_3_0320.wav
#
# Exracting features from D:\wav\s02a_8c_crisis_3_0321.wav
#
# Exracting features from D:\wav\s02a_8c_crisis_3_0322.wav
#
# Exracting features from D:\wav\s02a_8c_crisis_3_0323.wav
#
# Exracting features from D:\wav\s02a_8c_crisis_3_0324.wav
#
# Exracting features from D:\wav\s02a_8c_crisis_3_0325.wav
#
# Exracting features from D:\wav\s02a_8c_crisis_3_0326.wav
#
# Exracting features from D:\wav\s02a_8c_crisis_3_0327.wav
#
# Exracting features from D:\wav\s02a_8c_crisis_3_0328.wav
#
# Exracting features from D:\wav\s02a_8c_crisis_3_0329.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0330.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0331.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0332.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0333.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0334.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0335.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0336.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0337.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0338.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0339.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0340.wav
#
# Exracting features from D:\wav\s02a_9a_crisis_1_0341.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0342.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0343.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0344.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0345.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0346.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0347.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0348.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0349.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0350.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0351.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0352.wav
#
# Exracting features from D:\wav\s02a_9b_crisis_2_0353.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0354.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0355.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0356.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0357.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0358.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0359.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0360.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0361.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0362.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0363.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0364.wav
#
# Exracting features from D:\wav\s02a_9c_crisis_3_0365.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0305.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0306.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0307.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0308.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0309.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0310.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0311.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0312.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0313.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0314.wav
#
# Exracting features from D:\wav\s03a_10a_crisis_1_0315.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0316.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0317.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0318.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0319.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0320.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0321.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0322.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0323.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0324.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0325.wav
#
# Exracting features from D:\wav\s03a_10b_crisis_2_0326.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0327.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0328.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0329.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0330.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0331.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0332.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0333.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0334.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0335.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0336.wav
#
# Exracting features from D:\wav\s03a_10c_crisis_3_0337.wav
#
# Exracting features from D:\wav\s03a_11a_crisis_1_0338.wav
#
# Exracting features from D:\wav\s03a_11a_crisis_1_0339.wav
#
# Exracting features from D:\wav\s03a_11a_crisis_1_0340.wav
#
# Exracting features from D:\wav\s03a_11a_crisis_1_0341.wav
#
# Exracting features from D:\wav\s03a_11a_crisis_1_0342.wav
#
# Exracting features from D:\wav\s03a_11a_crisis_1_0343.wav
#
# Exracting features from D:\wav\s03a_11a_crisis_1_0344.wav
#
# Exracting features from D:\wav\s03a_11a_crisis_1_0345.wav
#
# Exracting features from D:\wav\s03a_11a_crisis_1_0346.wav
#
# Exracting features from D:\wav\s03a_11a_crisis_1_0347.wav
#
# Exracting features from D:\wav\s03a_12a_crisis_1_0348.wav
#
# Exracting features from D:\wav\s03a_12a_crisis_1_0349.wav
#
# Exracting features from D:\wav\s03a_12a_crisis_1_0350.wav
#
# Exracting features from D:\wav\s03a_12a_crisis_1_0351.wav
#
# Exracting features from D:\wav\s03a_12a_crisis_1_0352.wav
#
# Exracting features from D:\wav\s03a_12a_crisis_1_0353.wav
#
# Exracting features from D:\wav\s03a_12a_crisis_1_0354.wav
#
# Exracting features from D:\wav\s03a_12a_crisis_1_0355.wav
#
# Exracting features from D:\wav\s03a_12a_crisis_1_0356.wav
#
# Exracting features from D:\wav\s03a_12a_crisis_1_0357.wav
#
# Exracting features from D:\wav\s03a_1a_crisis_1_0001.wav
#
# Exracting features from D:\wav\s03a_1a_crisis_1_0002.wav
#
# Exracting features from D:\wav\s03a_1a_crisis_1_0003.wav
#
# Exracting features from D:\wav\s03a_1a_crisis_1_0004.wav
#
# Exracting features from D:\wav\s03a_1a_crisis_1_0005.wav
#
# Exracting features from D:\wav\s03a_1a_crisis_1_0006.wav
#
# Exracting features from D:\wav\s03a_1a_crisis_1_0007.wav
#
# Exracting features from D:\wav\s03a_1a_crisis_1_0008.wav
#
# Exracting features from D:\wav\s03a_1a_crisis_1_0009.wav
#
# Exracting features from D:\wav\s03a_1a_crisis_1_0010.wav
# Exracting features from D:\wav\s03a_1a_crisis_1_0011.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0012.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0013.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0014.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0015.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0016.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0017.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0018.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0019.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0020.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0021.wav
#
# Exracting features from D:\wav\s03a_1b_crisis_2_0022.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0023.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0024.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0025.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0026.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0027.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0028.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0029.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0030.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0031.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0032.wav
#
# Exracting features from D:\wav\s03a_1c_crisis_3_0033.wav
#
# Exracting features from D:\wav\s03a_2a_crisis_1_0034.wav
#
# Exracting features from D:\wav\s03a_2a_crisis_1_0035.wav
#
# Exracting features from D:\wav\s03a_2a_crisis_1_0036.wav
#
# Exracting features from D:\wav\s03a_2a_crisis_1_0037.wav
#
# Exracting features from D:\wav\s03a_2a_crisis_1_0038.wav
#
# Exracting features from D:\wav\s03a_2a_crisis_1_0039.wav
#
# Exracting features from D:\wav\s03a_2a_crisis_1_0040.wav
#
# Exracting features from D:\wav\s03a_2a_crisis_1_0041.wav
#
# Exracting features from D:\wav\s03a_2a_crisis_1_0042.wav
#
# Exracting features from D:\wav\s03a_2a_crisis_1_0043.wav
#
# Exracting features from D:\wav\s03a_2b_crisis_2_0044.wav
#
# Exracting features from D:\wav\s03a_2b_crisis_2_0045.wav
#
# Exracting features from D:\wav\s03a_2b_crisis_2_0046.wav
#
# Exracting features from D:\wav\s03a_2b_crisis_2_0047.wav
#
# Exracting features from D:\wav\s03a_2b_crisis_2_0048.wav
#
# Exracting features from D:\wav\s03a_2b_crisis_2_0049.wav
#
# Exracting features from D:\wav\s03a_2b_crisis_2_0050.wav
#
# Exracting features from D:\wav\s03a_2b_crisis_2_0051.wav
#
# Exracting features from D:\wav\s03a_2b_crisis_2_0052.wav
#
# Exracting features from D:\wav\s03a_2b_crisis_2_0053.wav
#
# Exracting features from D:\wav\s03a_2c_crisis_3_0054.wav
#
# Exracting features from D:\wav\s03a_2c_crisis_3_0055.wav
#
# Exracting features from D:\wav\s03a_2c_crisis_3_0056.wav
#
# Exracting features from D:\wav\s03a_2c_crisis_3_0057.wav
#
# Exracting features from D:\wav\s03a_2c_crisis_3_0058.wav
#
# Exracting features from D:\wav\s03a_2c_crisis_3_0059.wav
#
# Exracting features from D:\wav\s03a_2c_crisis_3_0060.wav
#
# Exracting features from D:\wav\s03a_2c_crisis_3_0061.wav
#
# Exracting features from D:\wav\s03a_2c_crisis_3_0062.wav
#
# Exracting features from D:\wav\s03a_2c_crisis_3_0063.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0064.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0065.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0066.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0067.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0068.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0069.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0070.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0071.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0072.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0073.wav
#
# Exracting features from D:\wav\s03a_3a_crisis_1_0074.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0075.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0076.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0077.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0078.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0079.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0080.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0081.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0082.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0083.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0084.wav
#
# Exracting features from D:\wav\s03a_3b_crisis_2_0085.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0086.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0087.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0088.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0089.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0090.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0091.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0092.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0093.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0094.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0095.wav
#
# Exracting features from D:\wav\s03a_3c_crisis_3_0096.wav
#
# Exracting features from D:\wav\s03a_4a_crisis_1_0097.wav
#
# Exracting features from D:\wav\s03a_4a_crisis_1_0098.wav
#
# Exracting features from D:\wav\s03a_4a_crisis_1_0099.wav
#
# Exracting features from D:\wav\s03a_4a_crisis_1_0100.wav
#
# ...
#
# Exracting features from D:\wav\s29h_1c_crisis_3_0029.wav
#
# Exracting features from D:\wav\s29h_1c_crisis_3_0030.wav
#
# Exracting features from D:\wav\s29h_1c_crisis_3_0031.wav
#
# Exracting features from D:\wav\s29h_1c_crisis_3_0032.wav
#
# Exracting features from D:\wav\s29h_1c_crisis_3_0033.wav
#
# Exracting features from D:\wav\s29h_2a_crisis_1_0034.wav
#
# Exracting features from D:\wav\s29h_2a_crisis_1_0035.wav
#
# Exracting features from D:\wav\s29h_2a_crisis_1_0036.wav
# Exracting features from D:\wav\s29h_2a_crisis_1_0037.wav
#
# Exracting features from D:\wav\s29h_2a_crisis_1_0038.wav
#
# Exracting features from D:\wav\s29h_2a_crisis_1_0039.wav
#
# Exracting features from D:\wav\s29h_2a_crisis_1_0040.wav
#
# Exracting features from D:\wav\s29h_2a_crisis_1_0041.wav
#
# Exracting features from D:\wav\s29h_2a_crisis_1_0042.wav
#
# Exracting features from D:\wav\s29h_2a_crisis_1_0043.wav
#
# Exracting features from D:\wav\s29h_2b_crisis_2_0044.wav
#
# Exracting features from D:\wav\s29h_2b_crisis_2_0045.wav
#
# Exracting features from D:\wav\s29h_2b_crisis_2_0046.wav
#
# Exracting features from D:\wav\s29h_2b_crisis_2_0047.wav
#
# Exracting features from D:\wav\s29h_2b_crisis_2_0048.wav
#
# Exracting features from D:\wav\s29h_2b_crisis_2_0049.wav
#
# Exracting features from D:\wav\s29h_2b_crisis_2_0050.wav
#
# Exracting features from D:\wav\s29h_2b_crisis_2_0051.wav
#
# Exracting features from D:\wav\s29h_2b_crisis_2_0052.wav
#
# Exracting features from D:\wav\s29h_2b_crisis_2_0053.wav
#
# Exracting features from D:\wav\s29h_2c_crisis_3_0054.wav
#
# Exracting features from D:\wav\s29h_2c_crisis_3_0055.wav
#
# Exracting features from D:\wav\s29h_2c_crisis_3_0056.wav
#
# Exracting features from D:\wav\s29h_2c_crisis_3_0057.wav
#
# Exracting features from D:\wav\s29h_2c_crisis_3_0058.wav
#
# Exracting features from D:\wav\s29h_2c_crisis_3_0059.wav
#
# Exracting features from D:\wav\s29h_2c_crisis_3_0060.wav
#
# Exracting features from D:\wav\s29h_2c_crisis_3_0061.wav
#
# Exracting features from D:\wav\s29h_2c_crisis_3_0062.wav
#
# Exracting features from D:\wav\s29h_2c_crisis_3_0063.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0064.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0065.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0066.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0067.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0068.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0069.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0070.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0071.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0072.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0073.wav
#
# Exracting features from D:\wav\s29h_3a_crisis_1_0074.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0075.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0076.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0077.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0078.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0079.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0080.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0081.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0082.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0083.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0084.wav
#
# Exracting features from D:\wav\s29h_3b_crisis_2_0085.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0086.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0087.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0088.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0089.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0090.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0091.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0092.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0093.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0094.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0095.wav
#
# Exracting features from D:\wav\s29h_3c_crisis_3_0096.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0097.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0098.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0099.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0100.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0101.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0102.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0103.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0104.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0105.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0106.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0107.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0108.wav
#
# Exracting features from D:\wav\s29h_4a_crisis_1_0109.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0110.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0111.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0112.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0113.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0114.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0115.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0116.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0117.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0118.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0119.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0120.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0121.wav
#
# Exracting features from D:\wav\s29h_4b_crisis_2_0122.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0123.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0124.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0125.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0126.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0127.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0128.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0129.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0130.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0131.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0132.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0133.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0134.wav
#
# Exracting features from D:\wav\s29h_4c_crisis_3_0135.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0136.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0137.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0138.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0139.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0140.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0141.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0142.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0143.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0144.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0145.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0146.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0147.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0148.wav
#
# Exracting features from D:\wav\s29h_5a_crisis_1_0149.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0150.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0151.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0152.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0153.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0154.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0155.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0156.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0157.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0158.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0159.wav
# Exracting features from D:\wav\s29h_5b_crisis_2_0160.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0161.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0162.wav
#
# Exracting features from D:\wav\s29h_5b_crisis_2_0163.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0164.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0165.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0166.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0167.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0168.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0169.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0170.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0171.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0172.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0173.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0174.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0175.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0176.wav
#
# Exracting features from D:\wav\s29h_5c_crisis_3_0177.wav
#
# Exracting features from D:\wav\s29h_6a_crisis_1_0178.wav
#
# Exracting features from D:\wav\s29h_6a_crisis_1_0179.wav
#
# Exracting features from D:\wav\s29h_6a_crisis_1_0180.wav
#
# Exracting features from D:\wav\s29h_6a_crisis_1_0181.wav
#
# Exracting features from D:\wav\s29h_6a_crisis_1_0182.wav
#
# Exracting features from D:\wav\s29h_6a_crisis_1_0183.wav
#
# Exracting features from D:\wav\s29h_6a_crisis_1_0184.wav
#
# Exracting features from D:\wav\s29h_6a_crisis_1_0185.wav
#
# Exracting features from D:\wav\s29h_6a_crisis_1_0186.wav
#
# Exracting features from D:\wav\s29h_6a_crisis_1_0187.wav
#
# Exracting features from D:\wav\s29h_6b_crisis_2_0188.wav
#
# Exracting features from D:\wav\s29h_6b_crisis_2_0189.wav
#
# Exracting features from D:\wav\s29h_6b_crisis_2_0190.wav
#
# Exracting features from D:\wav\s29h_6b_crisis_2_0191.wav
#
# Exracting features from D:\wav\s29h_6b_crisis_2_0192.wav
#
# Exracting features from D:\wav\s29h_6b_crisis_2_0193.wav
#
# Exracting features from D:\wav\s29h_6b_crisis_2_0194.wav
#
# Exracting features from D:\wav\s29h_6b_crisis_2_0195.wav
#
# Exracting features from D:\wav\s29h_6b_crisis_2_0196.wav
#
# Exracting features from D:\wav\s29h_6b_crisis_2_0197.wav
#
# Exracting features from D:\wav\s29h_6c_crisis_3_0198.wav
#
# Exracting features from D:\wav\s29h_6c_crisis_3_0199.wav
#
# Exracting features from D:\wav\s29h_6c_crisis_3_0200.wav
#
# Exracting features from D:\wav\s29h_6c_crisis_3_0201.wav
#
# Exracting features from D:\wav\s29h_6c_crisis_3_0202.wav
#
# Exracting features from D:\wav\s29h_6c_crisis_3_0203.wav
#
# Exracting features from D:\wav\s29h_6c_crisis_3_0204.wav
#
# Exracting features from D:\wav\s29h_6c_crisis_3_0205.wav
#
# Exracting features from D:\wav\s29h_6c_crisis_3_0206.wav
#
# Exracting features from D:\wav\s29h_6c_crisis_3_0207.wav
#
# Exracting features from D:\wav\s29h_7a_crisis_1_0208.wav
#
# Exracting features from D:\wav\s29h_7a_crisis_1_0209.wav
#
# Exracting features from D:\wav\s29h_7a_crisis_1_0210.wav
#
# Exracting features from D:\wav\s29h_7a_crisis_1_0211.wav
#
# Exracting features from D:\wav\s29h_7a_crisis_1_0212.wav
#
# Exracting features from D:\wav\s29h_7a_crisis_1_0213.wav
#
# Exracting features from D:\wav\s29h_7a_crisis_1_0214.wav
#
# Exracting features from D:\wav\s29h_7a_crisis_1_0215.wav
#
# Exracting features from D:\wav\s29h_7a_crisis_1_0216.wav
#
# Exracting features from D:\wav\s29h_7a_crisis_1_0217.wav
#
# Exracting features from D:\wav\s29h_7b_crisis_2_0218.wav
#
# Exracting features from D:\wav\s29h_7b_crisis_2_0219.wav
#
# Exracting features from D:\wav\s29h_7b_crisis_2_0220.wav
#
# Exracting features from D:\wav\s29h_7b_crisis_2_0221.wav
#
# Exracting features from D:\wav\s29h_7b_crisis_2_0222.wav
#
# Exracting features from D:\wav\s29h_7b_crisis_2_0223.wav
#
# Exracting features from D:\wav\s29h_7b_crisis_2_0224.wav
#
# Exracting features from D:\wav\s29h_7b_crisis_2_0225.wav
#
# Exracting features from D:\wav\s29h_7b_crisis_2_0226.wav
#
# Exracting features from D:\wav\s29h_7b_crisis_2_0227.wav
#
# Exracting features from D:\wav\s29h_7c_crisis_3_0228.wav
#
# Exracting features from D:\wav\s29h_7c_crisis_3_0229.wav
#
# Exracting features from D:\wav\s29h_7c_crisis_3_0230.wav
#
# Exracting features from D:\wav\s29h_7c_crisis_3_0231.wav
#
# Exracting features from D:\wav\s29h_7c_crisis_3_0232.wav
#
# Exracting features from D:\wav\s29h_7c_crisis_3_0233.wav
#
# Exracting features from D:\wav\s29h_7c_crisis_3_0234.wav
#
# Exracting features from D:\wav\s29h_7c_crisis_3_0235.wav
#
# Exracting features from D:\wav\s29h_7c_crisis_3_0236.wav
#
# Exracting features from D:\wav\s29h_7c_crisis_3_0237.wav
#
# Exracting features from D:\wav\s29h_8a_crisis_1_0238.wav
#
# Exracting features from D:\wav\s29h_8a_crisis_1_0239.wav
#
# Exracting features from D:\wav\s29h_8a_crisis_1_0240.wav
#
# Exracting features from D:\wav\s29h_8a_crisis_1_0241.wav
#
# Exracting features from D:\wav\s29h_8a_crisis_1_0242.wav
#
# Exracting features from D:\wav\s29h_8a_crisis_1_0243.wav
#
# Exracting features from D:\wav\s29h_8a_crisis_1_0244.wav
#
# Exracting features from D:\wav\s29h_8a_crisis_1_0245.wav
#
# Exracting features from D:\wav\s29h_8a_crisis_1_0246.wav
#
# Exracting features from D:\wav\s29h_8a_crisis_1_0247.wav
#
# Exracting features from D:\wav\s29h_8b_crisis_2_0248.wav
#
# Exracting features from D:\wav\s29h_8b_crisis_2_0249.wav
#
# Exracting features from D:\wav\s29h_8b_crisis_2_0250.wav
#
# Exracting features from D:\wav\s29h_8b_crisis_2_0251.wav
#
# Exracting features from D:\wav\s29h_8b_crisis_2_0252.wav
#
# Exracting features from D:\wav\s29h_8b_crisis_2_0253.wav
#
# Exracting features from D:\wav\s29h_8b_crisis_2_0254.wav
#
# Exracting features from D:\wav\s29h_8b_crisis_2_0255.wav
#
# Exracting features from D:\wav\s29h_8b_crisis_2_0256.wav
#
# Exracting features from D:\wav\s29h_8b_crisis_2_0257.wav
#
# Exracting features from D:\wav\s29h_8c_crisis_3_0258.wav
#
# Exracting features from D:\wav\s29h_8c_crisis_3_0259.wav
#
# Exracting features from D:\wav\s29h_8c_crisis_3_0260.wav
#
# Exracting features from D:\wav\s29h_8c_crisis_3_0261.wav
#
# Exracting features from D:\wav\s29h_8c_crisis_3_0262.wav
#
# Exracting features from D:\wav\s29h_8c_crisis_3_0263.wav
#
# Exracting features from D:\wav\s29h_8c_crisis_3_0264.wav
#
# Exracting features from D:\wav\s29h_8c_crisis_3_0265.wav
#
# Exracting features from D:\wav\s29h_8c_crisis_3_0266.wav
#
# Exracting features from D:\wav\s29h_8c_crisis_3_0267.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0268.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0269.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0270.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0271.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0272.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0273.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0274.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0275.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0276.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0277.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0278.wav
#
# Exracting features from D:\wav\s29h_9a_crisis_1_0279.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0280.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0281.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0282.wav
# Exracting features from D:\wav\s29h_9b_crisis_2_0283.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0284.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0285.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0286.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0287.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0288.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0289.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0290.wav
#
# Exracting features from D:\wav\s29h_9b_crisis_2_0291.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0292.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0293.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0294.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0295.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0296.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0297.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0298.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0299.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0300.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0301.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0302.wav
#
# Exracting features from D:\wav\s29h_9c_crisis_3_0303.wav
#
# Done

# %%
# %reset -f

# %%
#!pip install audb

# Import pandas
import pandas as pd
import re
 
# reading csv file
df=pd.read_csv(r"D:\D drive\Stress project\plpfeatures.csv",sep=";")
search = []    
for values in df['name']:
    search.append(re.search(r'\w+\.(wav)', values).group())

df['name'] = search

# %%
#df.to_csv(r"D:\jaysrawfilefeatures.csv")
import pandas as pd
#df=pd.read_csv("D:\jaysfeatures.csv",sep=";")
df.head()
# Out:
#                          name  frameIndex  frameTime  PlpCC[0]  PlpCC[1]  \
# 0  s01a_10a_crisis_1_0265.wav           0       0.00 -1.663885 -0.737098
# 1  s01a_10a_crisis_1_0265.wav           1       0.01 -1.868920 -0.928902
# 2  s01a_10a_crisis_1_0265.wav           2       0.02 -1.663159 -0.630156
# 3  s01a_10a_crisis_1_0265.wav           3       0.03 -1.570083 -0.538448
# 4  s01a_10a_crisis_1_0265.wav           4       0.04 -1.737203 -0.536851
#
#    PlpCC[2]  PlpCC[3]  PlpCC[4]  PlpCC[5]  PlpCC[6]  ...  PlpCC_de_de[3]  \
# 0  0.103915 -0.109968 -0.391883 -0.483124 -0.842414  ...       -0.012235
# 1 -0.119008 -0.207692 -0.160485 -0.369051 -0.193113  ...       -0.016146
# 2  0.011892 -0.024256 -0.203142 -0.023649  0.131175  ...       -0.010215
# 3 -0.373148 -0.291777  0.087203 -0.008296  0.099200  ...        0.007314
# 4 -0.207287 -0.249048 -0.364213 -0.463899 -0.815225  ...        0.006140
#
#    PlpCC_de_de[4]  PlpCC_de_de[5]  PlpCC_de_de[6]  PlpCC_de_de[7]  \
# 0       -0.000737       -0.008915       -0.042392       -0.007391
# 1       -0.013243       -0.017937       -0.088046       -0.014299
# 2        0.005914       -0.013325       -0.092599       -0.019378
# 3        0.001084       -0.004045       -0.052537       -0.014455
# 4        0.014503        0.003133        0.016594       -0.007293
#
#    PlpCC_de_de[8]  PlpCC_de_de[9]  PlpCC_de_de[10]  PlpCC_de_de[11]  \
# 0       -0.003524        0.012117         0.002271         0.005564
# 1       -0.027027        0.041584         0.018264        -0.004048
# 2       -0.044900        0.031978         0.030659        -0.008393
# 3       -0.041891        0.011555         0.022983        -0.022939
# 4       -0.047118       -0.040700         0.017772        -0.017502
#
#    PlpCC_de_de[12]
# 0         0.005413
# 1         0.005851
# 2        -0.001609
# 3        -0.008808
# 4        -0.002942
#
# [5 rows x 42 columns]

# %%
from ast import literal_eval
df_1 = df.copy()
del df_1['frameIndex']
del df_1['frameTime']

df.drop(['frameIndex', 'frameTime','PlpCC_de[0]','PlpCC_de[1]','PlpCC_de[2]','PlpCC_de[3]','PlpCC_de[4]',
         'PlpCC_de[5]','PlpCC_de[6]','PlpCC_de[7]','PlpCC_de[8]','PlpCC_de[9]','PlpCC_de[10]','PlpCC_de[11]',
         'PlpCC_de[12]','PlpCC_de_de[0]','PlpCC_de_de[1]','PlpCC_de_de[2]','PlpCC_de_de[3]','PlpCC_de_de[4]',
         'PlpCC_de_de[5]','PlpCC_de_de[6]','PlpCC_de_de[7]','PlpCC_de_de[8]','PlpCC_de_de[9]','PlpCC_de_de[10]',
         'PlpCC_de_de[11]','PlpCC_de_de[12]'], axis=1, inplace=True)
df2=df.groupby('name').agg(lambda x: list(x))
df_2=df_1.groupby('name').agg(lambda x: list(x))
#df2['features'].apply(lambda x: ast.literal_eval(x)).tolist()

#For 13 features
df2['features']= df2.values.tolist()
df2.reset_index(level=0, inplace=True)
df2['name'] = df2['name'].str.replace('.wav','',regex=False)

#For 39 features
df_2['features']= df_2.values.tolist()
df_2.reset_index(level=0, inplace=True)
df_2['name'] = df_2['name'].str.replace('.wav','',regex=False)

#df2.head()

# %%
#For merging columns
df2.head()
# Out:
#                      name                                           PlpCC[0]  \
# 0  s01a_10a_crisis_1_0265  [-1.663885, -1.86892, -1.663159, -1.570083, -1...
# 1  s01a_10a_crisis_1_0266  [-1.578194, -1.457086, -1.538219, -1.606225, -...
# 2  s01a_10a_crisis_1_0267  [-1.353141, -1.579406, -1.703097, -1.554928, -...
# 3  s01a_10a_crisis_1_0268  [-1.717315, -1.866003, -1.816671, -1.642207, -...
# 4  s01a_10a_crisis_1_0269  [-1.526972, -1.680659, -1.661119, -1.685415, -...
#
#                                             PlpCC[1]  \
# 0  [-0.7370982, -0.9289024, -0.6301557, -0.538447...
# 1  [-0.7366442, -0.8166831, -0.6899719, -0.792871...
# 2  [-0.3391016, -0.5229098, -0.5956297, -0.677883...
# 3  [-0.9396165, -1.041005, -0.9811341, -0.8138151...
# 4  [-0.4413507, -0.6805058, -0.6026543, -0.448010...
#
#                                             PlpCC[2]  \
# 0  [0.1039149, -0.119008, 0.01189173, -0.3731481,...
# 1  [-0.1166293, -0.2334824, -0.1623333, -0.221459...
# 2  [-0.03327338, -0.1050597, -0.1573344, -0.09503...
# 3  [-0.1583082, -0.3387218, -0.1799762, -0.067722...
# 4  [0.1507766, -0.1250479, -0.04891806, 0.0749276...
#
#                                             PlpCC[3]  \
# 0  [-0.1099681, -0.2076923, -0.02425618, -0.29177...
# 1  [-0.6419331, -0.1510231, -0.3682531, -0.324887...
# 2  [-0.3633387, -0.2556423, -0.4397236, -0.238071...
# 3  [-0.567957, -0.6126249, -0.3233064, -0.4765093...
# 4  [0.3434275, 0.2488019, 0.06730703, 0.1141151, ...
#
#                                             PlpCC[4]  \
# 0  [-0.3918827, -0.1604845, -0.2031416, 0.0872033...
# 1  [-0.6458776, -0.3049268, -0.4627545, -0.489652...
# 2  [-0.2004343, 0.2355866, 0.1186906, 0.07682261,...
# 3  [-0.8960596, -0.5677089, -0.1893669, -0.137212...
# 4  [0.01657027, 0.4181527, 0.05215669, 0.141028, ...
#
#                                             PlpCC[5]  \
# 0  [-0.483124, -0.3690511, -0.02364895, -0.008295...
# 1  [-0.4731525, -0.04551341, -0.2911325, -0.18705...
# 2  [-0.2225426, 0.03090787, 0.05608585, -0.016011...
# 3  [-0.3724257, -0.1663058, 0.3764772, 0.7359881,...
# 4  [0.361001, 0.3403232, 0.04002497, 0.2365749, 0...
#
#                                             PlpCC[6]  \
# 0  [-0.8424135, -0.1931129, 0.1311753, 0.09920019...
# 1  [-0.560234, -0.2322693, -0.464836, -0.3123778,...
# 2  [-0.1032991, -0.02961868, 0.2679211, 0.0690062...
# 3  [-0.4426097, 0.2321934, -0.3702042, -0.0236862...
# 4  [0.1916459, 0.2051854, -0.1120656, -0.2254797,...
#
#                                             PlpCC[7]  \
# 0  [-0.05073114, 0.1863521, 0.06673629, -0.097624...
# 1  [0.1812292, -0.1848774, 0.1279637, 0.4024117, ...
# 2  [-0.2113026, -0.179564, 0.4813198, 0.5521699, ...
# 3  [-0.04199536, 0.3121789, -0.821615, -0.2696529...
# 4  [-0.1824832, 0.2168172, 0.4620496, 0.1142674, ...
#
#                                             PlpCC[8]  \
# 0  [-0.1231843, 0.04026317, 0.4233624, 0.0158182,...
# 1  [0.1129793, 0.2142342, 0.4138108, 0.1392826, 0...
# 2  [-0.03886024, 0.1947503, -0.005608621, 0.23302...
# 3  [0.1465161, 0.2773521, 0.4053017, -0.1731404, ...
# 4  [-0.5054568, -0.1014461, 0.2453671, 0.1116248,...
#
#                                             PlpCC[9]  \
# 0  [0.2907438, -0.09153078, 0.01533443, -0.196449...
# 1  [0.1480734, 0.08392267, -0.0828105, -0.1124274...
# 2  [-0.08602219, 0.3494888, 0.1301276, 0.6451484,...
# 3  [0.07641292, -0.2488331, 0.6524515, -0.0612662...
# 4  [-0.6476827, 0.0212524, -0.09350317, 0.2631838...
#
#                                            PlpCC[10]  \
# 0  [0.3835732, 0.4252305, -0.1701173, 0.08029491,...
# 1  [-0.009942692, -0.4365932, 0.05442004, -0.2632...
# 2  [-0.1224473, 0.4006745, 0.1851201, 0.07053235,...
# 3  [-0.1853958, -0.204941, -0.6222503, -0.2532308...
# 4  [-0.5815281, -0.1537179, 0.3308379, 0.02916364...
#
#                                            PlpCC[11]  \
# 0  [-0.2654143, -0.07771952, -0.2065075, -0.03799...
# 1  [0.03169781, -0.06790163, -0.08543701, -0.0772...
# 2  [-0.1717181, -0.1776716, 0.02818789, -0.184112...
# 3  [0.4330608, 0.1229866, 0.2872261, -0.03111085,...
# 4  [-0.2154834, -0.1418777, 0.2443842, 0.07773018...
#
#                                            PlpCC[12]  \
# 0  [1.996192, 1.949156, 2.042517, 2.074882, 2.051...
# 1  [2.153531, 2.100071, 2.095432, 2.085341, 2.011...
# 2  [2.044118, 2.030329, 2.021918, 2.066431, 1.977...
# 3  [1.987628, 1.946458, 2.134876, 2.131124, 2.073...
# 4  [1.903072, 1.835095, 1.885057, 1.877523, 1.884...
#
#                                             features
# 0  [[-1.663885, -1.86892, -1.663159, -1.570083, -...
# 1  [[-1.578194, -1.457086, -1.538219, -1.606225, ...
# 2  [[-1.353141, -1.579406, -1.703097, -1.554928, ...
# 3  [[-1.717315, -1.866003, -1.816671, -1.642207, ...
# 4  [[-1.526972, -1.680659, -1.661119, -1.685415, ...

# %%
df_2.head()
# Out:
#                      name                                           PlpCC[0]  \
# 0  s01a_10a_crisis_1_0265  [-1.663885, -1.86892, -1.663159, -1.570083, -1...
# 1  s01a_10a_crisis_1_0266  [-1.578194, -1.457086, -1.538219, -1.606225, -...
# 2  s01a_10a_crisis_1_0267  [-1.353141, -1.579406, -1.703097, -1.554928, -...
# 3  s01a_10a_crisis_1_0268  [-1.717315, -1.866003, -1.816671, -1.642207, -...
# 4  s01a_10a_crisis_1_0269  [-1.526972, -1.680659, -1.661119, -1.685415, -...
#
#                                             PlpCC[1]  \
# 0  [-0.7370982, -0.9289024, -0.6301557, -0.538447...
# 1  [-0.7366442, -0.8166831, -0.6899719, -0.792871...
# 2  [-0.3391016, -0.5229098, -0.5956297, -0.677883...
# 3  [-0.9396165, -1.041005, -0.9811341, -0.8138151...
# 4  [-0.4413507, -0.6805058, -0.6026543, -0.448010...
#
#                                             PlpCC[2]  \
# 0  [0.1039149, -0.119008, 0.01189173, -0.3731481,...
# 1  [-0.1166293, -0.2334824, -0.1623333, -0.221459...
# 2  [-0.03327338, -0.1050597, -0.1573344, -0.09503...
# 3  [-0.1583082, -0.3387218, -0.1799762, -0.067722...
# 4  [0.1507766, -0.1250479, -0.04891806, 0.0749276...
#
#                                             PlpCC[3]  \
# 0  [-0.1099681, -0.2076923, -0.02425618, -0.29177...
# 1  [-0.6419331, -0.1510231, -0.3682531, -0.324887...
# 2  [-0.3633387, -0.2556423, -0.4397236, -0.238071...
# 3  [-0.567957, -0.6126249, -0.3233064, -0.4765093...
# 4  [0.3434275, 0.2488019, 0.06730703, 0.1141151, ...
#
#                                             PlpCC[4]  \
# 0  [-0.3918827, -0.1604845, -0.2031416, 0.0872033...
# 1  [-0.6458776, -0.3049268, -0.4627545, -0.489652...
# 2  [-0.2004343, 0.2355866, 0.1186906, 0.07682261,...
# 3  [-0.8960596, -0.5677089, -0.1893669, -0.137212...
# 4  [0.01657027, 0.4181527, 0.05215669, 0.141028, ...
#
#                                             PlpCC[5]  \
# 0  [-0.483124, -0.3690511, -0.02364895, -0.008295...
# 1  [-0.4731525, -0.04551341, -0.2911325, -0.18705...
# 2  [-0.2225426, 0.03090787, 0.05608585, -0.016011...
# 3  [-0.3724257, -0.1663058, 0.3764772, 0.7359881,...
# 4  [0.361001, 0.3403232, 0.04002497, 0.2365749, 0...
#
#                                             PlpCC[6]  \
# 0  [-0.8424135, -0.1931129, 0.1311753, 0.09920019...
# 1  [-0.560234, -0.2322693, -0.464836, -0.3123778,...
# 2  [-0.1032991, -0.02961868, 0.2679211, 0.0690062...
# 3  [-0.4426097, 0.2321934, -0.3702042, -0.0236862...
# 4  [0.1916459, 0.2051854, -0.1120656, -0.2254797,...
#
#                                             PlpCC[7]  \
# 0  [-0.05073114, 0.1863521, 0.06673629, -0.097624...
# 1  [0.1812292, -0.1848774, 0.1279637, 0.4024117, ...
# 2  [-0.2113026, -0.179564, 0.4813198, 0.5521699, ...
# 3  [-0.04199536, 0.3121789, -0.821615, -0.2696529...
# 4  [-0.1824832, 0.2168172, 0.4620496, 0.1142674, ...
#
#                                             PlpCC[8]  ...  \
# 0  [-0.1231843, 0.04026317, 0.4233624, 0.0158182,...  ...
# 1  [0.1129793, 0.2142342, 0.4138108, 0.1392826, 0...  ...
# 2  [-0.03886024, 0.1947503, -0.005608621, 0.23302...  ...
# 3  [0.1465161, 0.2773521, 0.4053017, -0.1731404, ...  ...
# 4  [-0.5054568, -0.1014461, 0.2453671, 0.1116248,...  ...
#
#                                       PlpCC_de_de[4]  \
# 0  [-0.000736751, -0.01324265, 0.005913845, 0.001...
# 1  [-0.001225739, -0.01541106, -0.01716948, -0.02...
# 2  [-0.01670554, -0.03529171, -0.04018787, -0.018...
# 3  [0.01242415, -0.01889465, -0.07267553, -0.1328...
# 4  [-0.02208526, -0.04231898, -0.04595991, -0.019...
#
#                                       PlpCC_de_de[5]  \
# 0  [-0.008915277, -0.01793678, -0.0133248, -0.004...
# 1  [-0.007295577, -0.0191777, -0.01374556, -0.002...
# 2  [-0.009241028, -0.007264073, -0.0001454674, 0....
# 3  [0.0195704, -0.03149195, -0.0908712, -0.115686...
# 4  [-0.001951906, 0.005034205, 0.004277126, 0.014...
#
#                                       PlpCC_de_de[6]  \
# 0  [-0.04239237, -0.08804586, -0.09259943, -0.052...
# 1  [0.00558451, -0.007517053, 0.01033153, 0.02049...
# 2  [0.001940114, -0.01183272, -0.04406453, -0.048...
# 3  [-0.007877685, -0.02537478, -0.009972252, -0.0...
# 4  [0.000205176, 0.01617425, 0.02453404, 0.029394...
#
#                                       PlpCC_de_de[7]  \
# 0  [-0.00739129, -0.01429946, -0.01937769, -0.014...
# 1  [0.01834132, 0.01275204, 0.009762154, -0.00948...
# 2  [0.02182957, -0.01126359, -0.06603458, -0.0966...
# 3  [0.02305272, 0.0440181, 0.09178346, 0.05043507...
# 4  [-0.02345718, -0.05599336, -0.06083248, -0.022...
#
#                                       PlpCC_de_de[8]  \
# 0  [-0.003523704, -0.02702699, -0.04489969, -0.04...
# 1  [-0.01436635, -0.03019354, -0.03089639, -0.023...
# 2  [0.0184526, 0.003389275, -0.01131294, -0.03456...
# 3  [-0.03738173, -0.0424538, -0.02127167, -0.0065...
# 4  [-0.01324549, -0.04485798, -0.05711482, -0.048...
#
#                                       PlpCC_de_de[9]  \
# 0  [0.01211677, 0.04158425, 0.03197765, 0.0115555...
# 1  [0.009193818, 0.02612385, 0.04107446, 0.036998...
# 2  [0.02909089, 0.008478804, -0.03156526, -0.0985...
# 3  [-0.01697595, -0.005300302, 0.005005206, 0.048...
# 4  [-0.003671424, -0.03951196, -0.05282715, -0.06...
#
#                                      PlpCC_de_de[10]  \
# 0  [0.002270991, 0.01826439, 0.03065946, 0.022983...
# 1  [0.00782858, 0.03152464, 0.03229388, 0.0272517...
# 2  [-0.03382026, -0.05154775, -0.0436693, -0.0309...
# 3  [0.01528101, 0.04464851, 0.03391567, -0.023334...
# 4  [-0.008995622, -0.04507551, -0.07604761, -0.06...
#
#                                      PlpCC_de_de[11]  \
# 0  [0.005563749, -0.004048003, -0.008392585, -0.0...
# 1  [-0.005023665, 0.007894538, 0.009350492, 0.021...
# 2  [-0.01352782, -0.01633878, -0.01214584, 0.0087...
# 3  [-0.01431133, -0.006756083, -0.005473672, 0.02...
# 4  [-0.000895489, 0.001232038, -0.02413944, -0.03...
#
#                                      PlpCC_de_de[12]  \
# 0  [0.005412546, 0.005850557, -0.001608671, -0.00...
# 1  [-0.002823541, -0.002681994, -0.001710663, 0.0...
# 2  [1.854189e-05, -0.00215085, -0.003240907, -0.0...
# 3  [0.003876413, 0.0004207538, -0.00197777, 0.005...
# 4  [0.00252155, 0.009385442, 0.008685515, 0.00539...
#
#                                             features
# 0  [[-1.663885, -1.86892, -1.663159, -1.570083, -...
# 1  [[-1.578194, -1.457086, -1.538219, -1.606225, ...
# 2  [[-1.353141, -1.579406, -1.703097, -1.554928, ...
# 3  [[-1.717315, -1.866003, -1.816671, -1.642207, ...
# 4  [[-1.526972, -1.680659, -1.661119, -1.685415, ...
#
# [5 rows x 41 columns]

# %%
header = ['name','features']
#df3 = df2.reindex(columns=header)
df2.to_csv(r"D:\D drive\Stress project\plpfeaturesready13.csv", columns = header, index=False, sep=',')
df_2.to_csv(r"D:\D drive\Stress project\plpfeaturesready39.csv", columns = header, index=False, sep=',')

# %%
#import pandas as pd
#import re
#df2=pd.read_csv("D:\jaysfeaturesready.csv",sep=",")
#df2.head()

# %%
#from ast import literal_eval
#import pandas as pd

# convert the column during import
#df2 = pd.read_csv("D:\jaysfeaturesready.csv",sep=",", converters={'features': literal_eval})

# %%
#df2['features'] = df2['features'].astype(float, errors = 'ignore')
#df2.features[0]
#header = ['name', 'features']
#df2.to_csv(r"D:\plpfeaturesready.csv", columns = header, index=False, sep=',')
# %reset -f

# %%
import numpy as np
import pandas as pd
import json
csv_data=pd.read_csv(r"D:\D drive\Stress project\plpfeaturesready39.csv", sep=',').values
temp = []
temp1 = []
dictlist = []
dictlist1 = []
for audio in csv_data:
#    audio_name=audio[0]
#    print(audio_name)
    features_string=audio[1]
    #x1=np.array(features_string,dtype=float)
    #x1=np.array([np.array(xi) for xi in features_string])
    #x1=np.fromstring(features_string,dtype=float)
    x1 = np.asarray(json.loads(features_string), dtype=np.float32)
    x2 = np.mean(x1.T,axis=0)
    temp = audio[0]
    temp1 = x2
    dictlist.append(temp)
    dictlist1.append(temp1)
df8 = pd.DataFrame(list(zip(dictlist, dictlist1)),
               columns =['FILE', 'features'])

# %%
import numpy as np
import pandas as pd
import json
max_pad=3376
csv_data=pd.read_csv(r"D:\D drive\Stress project\plpfeaturesready39.csv", sep=',').values
#csv_data=pd.read_csv('/home/jay_kejriwal/JAYBHAIcnn1.csv', sep=',').values
temp = []
temp1 = []
dictlist = []
dictlist1 = []
for audio in csv_data:
    features_string=audio[1]
    x1 = np.asarray(json.loads(features_string), dtype=np.float32)
    pad_width = max_pad - x1.shape[1]
    x2 = np.pad(x1, pad_width=((0, 0), (0, pad_width)), mode='constant')
    temp = audio[0]
    temp1 = x2
    dictlist.append(temp)
    dictlist1.append(temp1)
df9 = pd.DataFrame(list(zip(dictlist, dictlist1)),columns =['FILE', 'features'])

# %%
#df2['features']=df2['features'].apply(np.array)
#df2['features'] = df2['features'].apply(lambda x: x.astype('float'))
#np.amax(df8['features'])
df8.to_pickle("xxxxplp_features3376_39features_1D.pkl",protocol=4)
df9.to_pickle("xxxxplp_features3376_39features_2D.pkl",protocol=4)

# %%
df8
# Out:
#                          FILE  \
# 0      s01a_10a_crisis_1_0265
# 1      s01a_10a_crisis_1_0266
# 2      s01a_10a_crisis_1_0267
# 3      s01a_10a_crisis_1_0268
# 4      s01a_10a_crisis_1_0269
# ...                       ...
# 13591   s29h_9c_crisis_3_0299
# 13592   s29h_9c_crisis_3_0300
# 13593   s29h_9c_crisis_3_0301
# 13594   s29h_9c_crisis_3_0302
# 13595   s29h_9c_crisis_3_0303
#
#                                                 features
# 0      [-1.181526, -1.1501905, -0.49603552, -1.723175...
# 1      [-1.1566297, -1.149907, -0.49398357, -1.554585...
# 2      [-1.2651131, -1.2642878, -0.44951236, -1.47960...
# 3      [-1.3291821, -1.1043979, -0.44372857, -1.40596...
# 4      [-1.3881211, -1.1615074, -0.3616993, -1.570249...
# ...                                                  ...
# 13591  [-1.6096715, -1.4182185, -1.2178836, -1.847641...
# 13592  [-1.6572328, -1.1417557, -0.7779971, -2.150929...
# 13593  [-1.5127667, -1.4176596, -0.9306825, -1.705826...
# 13594  [-1.5993673, -1.1044931, -0.93501174, -1.77940...
# 13595  [-1.6086233, -1.2089908, -0.9550863, -2.061968...
#
# [13596 rows x 2 columns]

# %%
df8['features'].shape
# Out:
# (13596,)

# %%
df9
# Out:
#                          FILE  \
# 0      s01a_10a_crisis_1_0265
# 1      s01a_10a_crisis_1_0266
# 2      s01a_10a_crisis_1_0267
# 3      s01a_10a_crisis_1_0268
# 4      s01a_10a_crisis_1_0269
# ...                       ...
# 13591   s29h_9c_crisis_3_0299
# 13592   s29h_9c_crisis_3_0300
# 13593   s29h_9c_crisis_3_0301
# 13594   s29h_9c_crisis_3_0302
# 13595   s29h_9c_crisis_3_0303
#
#                                                 features
# 0      [[-1.663885, -1.86892, -1.663159, -1.570083, -...
# 1      [[-1.578194, -1.457086, -1.538219, -1.606225, ...
# 2      [[-1.353141, -1.579406, -1.703097, -1.554928, ...
# 3      [[-1.717315, -1.866003, -1.816671, -1.642207, ...
# 4      [[-1.526972, -1.680659, -1.661119, -1.685415, ...
# ...                                                  ...
# 13591  [[-2.495761, -2.648564, -2.730574, -2.791418, ...
# 13592  [[-2.458271, -2.16946, -2.230644, -2.794156, -...
# 13593  [[-2.179228, -2.212185, -2.429869, -2.467379, ...
# 13594  [[-2.94321, -3.053974, -3.042298, -2.92829, -2...
# 13595  [[-2.343339, -2.505483, -2.417103, -2.381579, ...
#
# [13596 rows x 2 columns]

# %%
metadata=pd.read_csv(r'C:\Users\Jay Kejriwal\Desktop\Jay\StressDat\modified.csv',sep="\t")

metadata.rename(columns={'V1': 'FILE', 'V2': 'Annotators', 'V3': 'SCORE'}, inplace=True)
# display updated DataFrame
metadata.head()
# Out:
#                      FILE  Annotators      SCORE   SCALE
# 0  s06h_10b_crisis_2_0315           2  28.846021  Medium
# 1   s01a_6b_crisis_2_0170           2  32.322045  Medium
# 2   s07n_8a_crisis_1_0244           1  17.074338  Medium
# 3   s06h_9b_crisis_2_0284           2  43.659132    High
# 4   s03a_9a_crisis_1_0274           1  27.351947  Medium

# %%
import pandas as pd
import os
import librosa
import numpy as np
audio_dataset_path=r'C:\Users\Jay Kejriwal\Desktop\Jay\StressDat'
header_list = ["FILE", "Annotators", "SCORE"]
metadata=pd.read_csv(r'C:\Users\Jay Kejriwal\Desktop\Jay\StressDat\StressDat-anotacia-29spk_v1_normalize_all_scores.txt',sep="\t",names=header_list)
conditions = [
    (metadata['SCORE'] <= 20),
    (metadata['SCORE'] > 20) & (metadata['SCORE'] <= 40),
    (metadata['SCORE'] > 40)
    ]

# create a list of the values we want to assign for each condition
values = ['low', 'med', 'high']

# create a new column and use np.select to assign values to it using our lists as arguments
metadata['SCALE'] = np.select(conditions, values)
# display updated DataFrame
metadata.head()
# Out:
#                      FILE  Annotators      SCORE SCALE
# 0  s06h_10b_crisis_2_0315           2  28.846021   med
# 1   s01a_6b_crisis_2_0170           2  32.322045   med
# 2   s07n_8a_crisis_1_0244           1  17.074338   low
# 3   s06h_9b_crisis_2_0284           2  43.659132  high
# 4   s07n_6a_crisis_1_0180           1  11.215002   low

# %%
#Non normalized score
import pandas as pd
import os
import librosa
import numpy as np
audio_dataset_path=r'C:\Users\Jay Kejriwal\Desktop\Jay\StressDat'
#header_list = ["FILE", "Annotators", "SCORE"]
metadata=pd.read_csv(r'C:\Users\Jay Kejriwal\Desktop\Jay\StressDat\StressDat-anotacia-29spk_v1_normalized.txt',sep="\t")
conditions = [
    (metadata['SCORE'] <= 20),
    (metadata['SCORE'] > 20) & (metadata['SCORE'] <= 40),
    (metadata['SCORE'] > 40)
    ]

# create a list of the values we want to assign for each condition
values = ['low', 'med', 'high']

# create a new column and use np.select to assign values to it using our lists as arguments
metadata['SCALE'] = np.select(conditions, values)
# display updated DataFrame
metadata.head()

# %%
#df4=df3.rename(columns={'name':'FILE'})
#df3=df2.rename(columns={"name": "FILE"}, inplace=True)

# %%
#import pandas as pd
#df=pd.read_csv("D:\jaysfeaturesready.csv",sep=",",encoding='utf-8-sig')

# %%
#metadata

# %%
#df3

# %%
import pandas as pd
X1= pd.merge(metadata, df8, on='FILE', how='inner')
X2= pd.merge(metadata, df9, on='FILE', how='inner')

# %%
X1
# Out:
#                          FILE  Annotators      SCORE   SCALE  \
# 0      s06h_10b_crisis_2_0315           2  28.846021  Medium
# 1       s01a_6b_crisis_2_0170           2  32.322045  Medium
# 2       s07n_8a_crisis_1_0244           1  17.074338  Medium
# 3       s06h_9b_crisis_2_0284           2  43.659132    High
# 4       s03a_9a_crisis_1_0274           1  27.351947  Medium
# ...                       ...         ...        ...     ...
# 12784  s29h_18a_crisis_1_0493           1  11.326830     Low
# 12785  s27h_19a_crisis_1_0537           1   5.753345     Low
# 12786  s26h_16b_crisis_2_0444           2  32.758280  Medium
# 12787  s25h_19a_crisis_1_0526           1   5.866519     Low
# 12788  s21h_16c_crisis_3_0472           3  50.199180    High
#
#                                                 features
# 0      [-1.3457141, -0.84479815, -0.8052901, -1.30199...
# 1      [-1.2778603, -1.4050884, -0.5534877, -1.382199...
# 2      [-1.0534563, -1.0862665, -0.6522909, -1.612935...
# 3      [-1.4526705, -0.94650483, -0.66287154, -1.0333...
# 4      [-1.8631258, -1.3204547, -1.1895173, -1.408662...
# ...                                                  ...
# 12784  [-1.5144806, -0.7311671, -0.6520798, -1.682670...
# 12785  [-1.7072542, -0.8461304, -0.7927792, -0.878702...
# 12786  [-0.8445784, -1.9796796, -0.29590932, -0.89218...
# 12787  [-1.8218334, -0.57455885, -0.34597924, -0.7662...
# 12788  [-1.9962379, -1.4135851, -1.6678615, -1.189008...
#
# [12789 rows x 5 columns]

# %%
X2
# Out:
#                          FILE  Annotators      SCORE   SCALE  \
# 0      s06h_10b_crisis_2_0315           2  28.846021  Medium
# 1       s01a_6b_crisis_2_0170           2  32.322045  Medium
# 2       s07n_8a_crisis_1_0244           1  17.074338  Medium
# 3       s06h_9b_crisis_2_0284           2  43.659132    High
# 4       s03a_9a_crisis_1_0274           1  27.351947  Medium
# ...                       ...         ...        ...     ...
# 12784  s29h_18a_crisis_1_0493           1  11.326830     Low
# 12785  s27h_19a_crisis_1_0537           1   5.753345     Low
# 12786  s26h_16b_crisis_2_0444           2  32.758280  Medium
# 12787  s25h_19a_crisis_1_0526           1   5.866519     Low
# 12788  s21h_16c_crisis_3_0472           3  50.199180    High
#
#                                                 features
# 0      [[-1.739716, -1.798464, -1.854886, -1.917512, ...
# 1      [[-1.614713, -1.434759, -1.690286, -1.589449, ...
# 2      [[-1.347506, -1.42715, -1.508971, -1.348602, -...
# 3      [[-1.911707, -1.933435, -1.87926, -1.923083, -...
# 4      [[-1.920418, -2.278352, -2.565652, -2.363026, ...
# ...                                                  ...
# 12784  [[-2.012226, -2.113735, -2.406524, -2.432655, ...
# 12785  [[-1.940381, -2.05437, -1.852127, -1.926401, -...
# 12786  [[-1.755389, -2.010168, -2.171337, -2.204001, ...
# 12787  [[-2.125805, -2.158999, -2.133527, -2.23166, -...
# 12788  [[-2.245534, -2.58002, -2.136909, -1.049014, -...
#
# [12789 rows x 5 columns]

# %%
extracted_features_df = X1[["SCALE","features"]]
extracted_features_df.columns=['class_label','feature']
extracted_features_df.to_pickle("newplp_features3376_39features_1D.pkl",protocol=4)
extracted_features_df1 = X2[["SCALE","features"]]
extracted_features_df1.columns=['class_label','feature']
extracted_features_df1.to_pickle("newplp_features3376_39features_2D.pkl",protocol=4)

# %%
extracted_features_df['feature'].shape
# Out:
# (12814,)

# %%
extracted_features_df
# Out:
#       class                                            feature
# 0       med  [-1.254585, -0.57961816, -0.5781675, -0.757055...
# 1       med  [-1.154907, -1.201113, -0.24314202, -0.8835869...
# 2       low  [-0.839728, -0.7781066, -0.29093766, -1.175221...
# 3      high  [-1.3239641, -0.6585506, -0.3563403, -0.393836...
# 4       low  [-0.7987797, -0.8304411, -0.16805467, -1.05731...
# ...     ...                                                ...
# 12809   low  [-1.3418876, -0.43859497, -0.3007476, -1.11997...
# 12810   low  [-1.5591668, -0.6541791, -0.499975, -0.4337659...
# 12811   med  [-0.70156705, -1.8070072, 0.039682336, -0.2926...
# 12812   low  [-1.6196783, -0.3584443, -0.108755246, -0.2022...
# 12813  high  [-1.6645223, -0.9510826, -0.88076836, -0.18683...
#
# [12814 rows x 2 columns]

# %%
import numpy as np
X=np.array(extracted_features_df['feature'].tolist())
y=np.array(extracted_features_df['class'].tolist())

# %%
X.shape
# Out:
# (12814, 18)

# %%
y.shape
# Out:
# (12814,)

# %%
y
# Out:
# array(['med', 'med', 'low', ..., 'med', 'low', 'high'], dtype='<U4')

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y=np.array(extracted_features_df['class'].tolist())
y=to_categorical(labelencoder.fit_transform(y))

# %%
### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# %%
### No of classes
num_labels=y.shape[1]

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(18,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))

###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
#X_train[0]

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 321/321 [==============================] - 2s 4ms/step - loss: 1.1595 - accuracy: 0.3762 - val_loss: 1.0597 - val_accuracy: 0.4136
#
# Epoch 00001: val_loss improved from inf to 1.05968, saving model to saved_models\audio_classification.hdf5
# Epoch 2/100
# 321/321 [==============================] - 1s 2ms/step - loss: 1.0633 - accuracy: 0.4329 - val_loss: 0.9996 - val_accuracy: 0.5029
#
# Epoch 00002: val_loss improved from 1.05968 to 0.99961, saving model to saved_models\audio_classification.hdf5
# Epoch 3/100
# 321/321 [==============================] - 1s 2ms/step - loss: 1.0165 - accuracy: 0.4716 - val_loss: 0.9537 - val_accuracy: 0.5256
#
# Epoch 00003: val_loss improved from 0.99961 to 0.95371, saving model to saved_models\audio_classification.hdf5
# Epoch 4/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.9786 - accuracy: 0.5036 - val_loss: 0.8996 - val_accuracy: 0.5646
#
# Epoch 00004: val_loss improved from 0.95371 to 0.89957, saving model to saved_models\audio_classification.hdf5
# Epoch 5/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.9330 - accuracy: 0.5374 - val_loss: 0.8320 - val_accuracy: 0.6161
#
# Epoch 00005: val_loss improved from 0.89957 to 0.83201, saving model to saved_models\audio_classification.hdf5
# Epoch 6/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.8844 - accuracy: 0.5645 - val_loss: 0.7769 - val_accuracy: 0.6438
#
# Epoch 00006: val_loss improved from 0.83201 to 0.77688, saving model to saved_models\audio_classification.hdf5
# Epoch 7/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.8466 - accuracy: 0.5883 - val_loss: 0.7883 - val_accuracy: 0.6274
#
# Epoch 00007: val_loss did not improve from 0.77688
# Epoch 8/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.8260 - accuracy: 0.5961 - val_loss: 0.7389 - val_accuracy: 0.6707
#
# Epoch 00008: val_loss improved from 0.77688 to 0.73890, saving model to saved_models\audio_classification.hdf5
# Epoch 9/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.8076 - accuracy: 0.6043 - val_loss: 0.7425 - val_accuracy: 0.6672
#
# Epoch 00009: val_loss did not improve from 0.73890
# Epoch 10/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7949 - accuracy: 0.6180 - val_loss: 0.7613 - val_accuracy: 0.6344
#
# Epoch 00010: val_loss did not improve from 0.73890
# Epoch 11/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7933 - accuracy: 0.6219 - val_loss: 0.7392 - val_accuracy: 0.6621
#
# Epoch 00011: val_loss did not improve from 0.73890
# Epoch 12/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7908 - accuracy: 0.6238 - val_loss: 0.7253 - val_accuracy: 0.6726
#
# Epoch 00012: val_loss improved from 0.73890 to 0.72535, saving model to saved_models\audio_classification.hdf5
# Epoch 13/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7841 - accuracy: 0.6256 - val_loss: 0.7329 - val_accuracy: 0.6578
#
# Epoch 00013: val_loss did not improve from 0.72535
# Epoch 14/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7694 - accuracy: 0.6282 - val_loss: 0.7208 - val_accuracy: 0.6734
#
# Epoch 00014: val_loss improved from 0.72535 to 0.72078, saving model to saved_models\audio_classification.hdf5
# Epoch 15/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7518 - accuracy: 0.6478 - val_loss: 0.7117 - val_accuracy: 0.6711
#
# Epoch 00015: val_loss improved from 0.72078 to 0.71171, saving model to saved_models\audio_classification.hdf5
# Epoch 16/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7554 - accuracy: 0.6419 - val_loss: 0.7418 - val_accuracy: 0.6574
#
# Epoch 00016: val_loss did not improve from 0.71171
# Epoch 17/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7585 - accuracy: 0.6423 - val_loss: 0.7281 - val_accuracy: 0.6680
#
# Epoch 00017: val_loss did not improve from 0.71171
# Epoch 18/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7635 - accuracy: 0.6421 - val_loss: 0.7145 - val_accuracy: 0.6816
#
# Epoch 00018: val_loss did not improve from 0.71171
# Epoch 19/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7682 - accuracy: 0.6368 - val_loss: 0.7203 - val_accuracy: 0.6687
#
# Epoch 00019: val_loss did not improve from 0.71171
# Epoch 20/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7513 - accuracy: 0.6417 - val_loss: 0.7127 - val_accuracy: 0.6766
#
# Epoch 00020: val_loss did not improve from 0.71171
# Epoch 21/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7557 - accuracy: 0.6484 - val_loss: 0.7334 - val_accuracy: 0.6645
#
# Epoch 00021: val_loss did not improve from 0.71171
# Epoch 22/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7660 - accuracy: 0.6428 - val_loss: 0.7118 - val_accuracy: 0.6723
#
# Epoch 00022: val_loss did not improve from 0.71171
# Epoch 23/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7469 - accuracy: 0.6489 - val_loss: 0.7138 - val_accuracy: 0.6645
#
# Epoch 00023: val_loss did not improve from 0.71171
# Epoch 24/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7506 - accuracy: 0.6381 - val_loss: 0.7305 - val_accuracy: 0.6590
#
# Epoch 00024: val_loss did not improve from 0.71171
# Epoch 25/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7603 - accuracy: 0.6482 - val_loss: 0.7232 - val_accuracy: 0.6539
#
# Epoch 00025: val_loss did not improve from 0.71171
# Epoch 26/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7528 - accuracy: 0.6435 - val_loss: 0.7105 - val_accuracy: 0.6754
#
# Epoch 00026: val_loss improved from 0.71171 to 0.71055, saving model to saved_models\audio_classification.hdf5
# Epoch 27/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7412 - accuracy: 0.6457 - val_loss: 0.7091 - val_accuracy: 0.6801
#
# Epoch 00027: val_loss improved from 0.71055 to 0.70908, saving model to saved_models\audio_classification.hdf5
# Epoch 28/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7347 - accuracy: 0.6531 - val_loss: 0.7266 - val_accuracy: 0.6676
#
# Epoch 00028: val_loss did not improve from 0.70908
# Epoch 29/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7540 - accuracy: 0.6433 - val_loss: 0.7392 - val_accuracy: 0.6719
#
# Epoch 00029: val_loss did not improve from 0.70908
# Epoch 30/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7493 - accuracy: 0.6490 - val_loss: 0.7098 - val_accuracy: 0.6785
#
# Epoch 00030: val_loss did not improve from 0.70908
# Epoch 31/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7492 - accuracy: 0.6487 - val_loss: 0.7264 - val_accuracy: 0.6656
#
# Epoch 00031: val_loss did not improve from 0.70908
# Epoch 32/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7423 - accuracy: 0.6555 - val_loss: 0.7122 - val_accuracy: 0.6758
#
# Epoch 00032: val_loss did not improve from 0.70908
# Epoch 33/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7534 - accuracy: 0.6423 - val_loss: 0.7110 - val_accuracy: 0.6723
#
# Epoch 00033: val_loss did not improve from 0.70908
# Epoch 34/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7429 - accuracy: 0.6533 - val_loss: 0.7102 - val_accuracy: 0.6769
#
# Epoch 00034: val_loss did not improve from 0.70908
# Epoch 35/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7404 - accuracy: 0.6508 - val_loss: 0.7184 - val_accuracy: 0.6672
#
# Epoch 00035: val_loss did not improve from 0.70908
# Epoch 36/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7550 - accuracy: 0.6478 - val_loss: 0.7138 - val_accuracy: 0.6785
#
# Epoch 00036: val_loss did not improve from 0.70908
# Epoch 37/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7530 - accuracy: 0.6460 - val_loss: 0.7218 - val_accuracy: 0.6672
#
# Epoch 00037: val_loss did not improve from 0.70908
# Epoch 38/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7469 - accuracy: 0.6473 - val_loss: 0.7068 - val_accuracy: 0.6730
#
# Epoch 00038: val_loss improved from 0.70908 to 0.70683, saving model to saved_models\audio_classification.hdf5
# Epoch 39/100
# 321/321 [==============================] - 0s 2ms/step - loss: 0.7319 - accuracy: 0.6591 - val_loss: 0.7356 - val_accuracy: 0.6574
#
# Epoch 00039: val_loss did not improve from 0.70683
# Epoch 40/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7399 - accuracy: 0.6596 - val_loss: 0.7228 - val_accuracy: 0.6703
#
# Epoch 00040: val_loss did not improve from 0.70683
# Epoch 41/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7413 - accuracy: 0.6421 - val_loss: 0.7132 - val_accuracy: 0.6773
#
# Epoch 00041: val_loss did not improve from 0.70683
# Epoch 42/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7426 - accuracy: 0.6566 - val_loss: 0.7127 - val_accuracy: 0.6734
#
# Epoch 00042: val_loss did not improve from 0.70683
# Epoch 43/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7414 - accuracy: 0.6476 - val_loss: 0.7190 - val_accuracy: 0.6824
#
# Epoch 00043: val_loss did not improve from 0.70683
# Epoch 44/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7421 - accuracy: 0.6493 - val_loss: 0.7150 - val_accuracy: 0.6805
#
# Epoch 00044: val_loss did not improve from 0.70683
# Epoch 45/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7433 - accuracy: 0.6512 - val_loss: 0.7254 - val_accuracy: 0.6582
#
# Epoch 00045: val_loss did not improve from 0.70683
# Epoch 46/100
# 321/321 [==============================] - 0s 2ms/step - loss: 0.7420 - accuracy: 0.6530 - val_loss: 0.7050 - val_accuracy: 0.6715
#
# Epoch 00046: val_loss improved from 0.70683 to 0.70503, saving model to saved_models\audio_classification.hdf5
# Epoch 47/100
# 321/321 [==============================] - 0s 2ms/step - loss: 0.7510 - accuracy: 0.6524 - val_loss: 0.7149 - val_accuracy: 0.6691
#
# Epoch 00047: val_loss did not improve from 0.70503
# Epoch 48/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7410 - accuracy: 0.6516 - val_loss: 0.7011 - val_accuracy: 0.6793
#
# Epoch 00048: val_loss improved from 0.70503 to 0.70105, saving model to saved_models\audio_classification.hdf5
# Epoch 49/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7412 - accuracy: 0.6600 - val_loss: 0.7067 - val_accuracy: 0.6723
#
# Epoch 00049: val_loss did not improve from 0.70105
# Epoch 50/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7451 - accuracy: 0.6489 - val_loss: 0.7192 - val_accuracy: 0.6648
#
# Epoch 00050: val_loss did not improve from 0.70105
# Epoch 51/100
# 321/321 [==============================] - 0s 2ms/step - loss: 0.7333 - accuracy: 0.6603 - val_loss: 0.7146 - val_accuracy: 0.6734
#
# Epoch 00051: val_loss did not improve from 0.70105
# Epoch 52/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7430 - accuracy: 0.6552 - val_loss: 0.7024 - val_accuracy: 0.6773
#
# Epoch 00052: val_loss did not improve from 0.70105
# Epoch 53/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7360 - accuracy: 0.6526 - val_loss: 0.7180 - val_accuracy: 0.6660
#
# Epoch 00053: val_loss did not improve from 0.70105
# Epoch 54/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7254 - accuracy: 0.6555 - val_loss: 0.7141 - val_accuracy: 0.6703
#
# Epoch 00054: val_loss did not improve from 0.70105
# Epoch 55/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7415 - accuracy: 0.6527 - val_loss: 0.7018 - val_accuracy: 0.6769
#
# Epoch 00055: val_loss did not improve from 0.70105
# Epoch 56/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7356 - accuracy: 0.6536 - val_loss: 0.7265 - val_accuracy: 0.6629
#
# Epoch 00056: val_loss did not improve from 0.70105
# Epoch 57/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7408 - accuracy: 0.6519 - val_loss: 0.7183 - val_accuracy: 0.6758
#
# Epoch 00057: val_loss did not improve from 0.70105
# Epoch 58/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7351 - accuracy: 0.6595 - val_loss: 0.7141 - val_accuracy: 0.6684
#
# Epoch 00058: val_loss did not improve from 0.70105
# Epoch 59/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7442 - accuracy: 0.6516 - val_loss: 0.7136 - val_accuracy: 0.6742
#
# Epoch 00059: val_loss did not improve from 0.70105
# Epoch 60/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7358 - accuracy: 0.6526 - val_loss: 0.7358 - val_accuracy: 0.6586
#
# Epoch 00060: val_loss did not improve from 0.70105
# Epoch 61/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7366 - accuracy: 0.6589 - val_loss: 0.7050 - val_accuracy: 0.6687
#
# Epoch 00061: val_loss did not improve from 0.70105
# Epoch 62/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7328 - accuracy: 0.6458 - val_loss: 0.7008 - val_accuracy: 0.6816
#
# Epoch 00062: val_loss improved from 0.70105 to 0.70078, saving model to saved_models\audio_classification.hdf5
# Epoch 63/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7234 - accuracy: 0.6685 - val_loss: 0.7132 - val_accuracy: 0.6699
#
# Epoch 00063: val_loss did not improve from 0.70078
# Epoch 64/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7352 - accuracy: 0.6558 - val_loss: 0.7110 - val_accuracy: 0.6664
#
# Epoch 00064: val_loss did not improve from 0.70078
# Epoch 65/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7454 - accuracy: 0.6490 - val_loss: 0.7060 - val_accuracy: 0.6699
#
# Epoch 00065: val_loss did not improve from 0.70078
# Epoch 66/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7252 - accuracy: 0.6627 - val_loss: 0.7459 - val_accuracy: 0.6496
#
# Epoch 00066: val_loss did not improve from 0.70078
# Epoch 67/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7416 - accuracy: 0.6589 - val_loss: 0.7203 - val_accuracy: 0.6691
#
# Epoch 00067: val_loss did not improve from 0.70078
# Epoch 68/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7213 - accuracy: 0.6620 - val_loss: 0.7345 - val_accuracy: 0.6512
#
# Epoch 00068: val_loss did not improve from 0.70078
# Epoch 69/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7297 - accuracy: 0.6544 - val_loss: 0.7063 - val_accuracy: 0.6746
#
# Epoch 00069: val_loss did not improve from 0.70078
# Epoch 70/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7373 - accuracy: 0.6557 - val_loss: 0.7131 - val_accuracy: 0.6699
#
# Epoch 00070: val_loss did not improve from 0.70078
# Epoch 71/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7344 - accuracy: 0.6600 - val_loss: 0.7313 - val_accuracy: 0.6637
#
# Epoch 00071: val_loss did not improve from 0.70078
# Epoch 72/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7360 - accuracy: 0.6515 - val_loss: 0.7381 - val_accuracy: 0.6473
#
# Epoch 00072: val_loss did not improve from 0.70078
# Epoch 73/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7359 - accuracy: 0.6489 - val_loss: 0.7049 - val_accuracy: 0.6797
#
# Epoch 00073: val_loss did not improve from 0.70078
# Epoch 74/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7373 - accuracy: 0.6628 - val_loss: 0.7217 - val_accuracy: 0.6602
#
# Epoch 00074: val_loss did not improve from 0.70078
# Epoch 75/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7346 - accuracy: 0.6562 - val_loss: 0.7004 - val_accuracy: 0.6734
#
# Epoch 00075: val_loss improved from 0.70078 to 0.70043, saving model to saved_models\audio_classification.hdf5
# Epoch 76/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7415 - accuracy: 0.6519 - val_loss: 0.7186 - val_accuracy: 0.6672
#
# Epoch 00076: val_loss did not improve from 0.70043
# Epoch 77/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7444 - accuracy: 0.6562 - val_loss: 0.7154 - val_accuracy: 0.6781
#
# Epoch 00077: val_loss did not improve from 0.70043
# Epoch 78/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7434 - accuracy: 0.6477 - val_loss: 0.7150 - val_accuracy: 0.6703
#
# Epoch 00078: val_loss did not improve from 0.70043
# Epoch 79/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7403 - accuracy: 0.6473 - val_loss: 0.7134 - val_accuracy: 0.6703
#
# Epoch 00079: val_loss did not improve from 0.70043
# Epoch 80/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7476 - accuracy: 0.6446 - val_loss: 0.7140 - val_accuracy: 0.6695
#
# Epoch 00080: val_loss did not improve from 0.70043
# Epoch 81/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7370 - accuracy: 0.6484 - val_loss: 0.7063 - val_accuracy: 0.6730
#
# Epoch 00081: val_loss did not improve from 0.70043
# Epoch 82/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7333 - accuracy: 0.6585 - val_loss: 0.7261 - val_accuracy: 0.6574
#
# Epoch 00082: val_loss did not improve from 0.70043
# Epoch 83/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7313 - accuracy: 0.6601 - val_loss: 0.7137 - val_accuracy: 0.6684
#
# Epoch 00083: val_loss did not improve from 0.70043
# Epoch 84/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7401 - accuracy: 0.6507 - val_loss: 0.7335 - val_accuracy: 0.6648
#
# Epoch 00084: val_loss did not improve from 0.70043
# Epoch 85/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7245 - accuracy: 0.6640 - val_loss: 0.7263 - val_accuracy: 0.6586
#
# Epoch 00085: val_loss did not improve from 0.70043
# Epoch 86/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7451 - accuracy: 0.6534 - val_loss: 0.7082 - val_accuracy: 0.6672
#
# Epoch 00086: val_loss did not improve from 0.70043
# Epoch 87/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7331 - accuracy: 0.6639 - val_loss: 0.7085 - val_accuracy: 0.6758
#
# Epoch 00087: val_loss did not improve from 0.70043
# Epoch 88/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7223 - accuracy: 0.6597 - val_loss: 0.7162 - val_accuracy: 0.6664
#
# Epoch 00088: val_loss did not improve from 0.70043
# Epoch 89/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7286 - accuracy: 0.6653 - val_loss: 0.7187 - val_accuracy: 0.6719
#
# Epoch 00089: val_loss did not improve from 0.70043
# Epoch 90/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7223 - accuracy: 0.6660 - val_loss: 0.7344 - val_accuracy: 0.6715
#
# Epoch 00090: val_loss did not improve from 0.70043
# Epoch 91/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7388 - accuracy: 0.6452 - val_loss: 0.7180 - val_accuracy: 0.6629
#
# Epoch 00091: val_loss did not improve from 0.70043
# Epoch 92/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7271 - accuracy: 0.6542 - val_loss: 0.7056 - val_accuracy: 0.6773
#
# Epoch 00092: val_loss did not improve from 0.70043
# Epoch 93/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7185 - accuracy: 0.6690 - val_loss: 0.7271 - val_accuracy: 0.6641
#
# Epoch 00093: val_loss did not improve from 0.70043
# Epoch 94/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7325 - accuracy: 0.6590 - val_loss: 0.7080 - val_accuracy: 0.6754
#
# Epoch 00094: val_loss did not improve from 0.70043
# Epoch 95/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7337 - accuracy: 0.6624 - val_loss: 0.7013 - val_accuracy: 0.6812
#
# Epoch 00095: val_loss did not improve from 0.70043
# Epoch 96/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7346 - accuracy: 0.6439 - val_loss: 0.7163 - val_accuracy: 0.6711
#
# Epoch 00096: val_loss did not improve from 0.70043
# Epoch 97/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7372 - accuracy: 0.6520 - val_loss: 0.7119 - val_accuracy: 0.6758
#
# Epoch 00097: val_loss did not improve from 0.70043
# Epoch 98/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7352 - accuracy: 0.6502 - val_loss: 0.7098 - val_accuracy: 0.6711
#
# Epoch 00098: val_loss did not improve from 0.70043
# Epoch 99/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7417 - accuracy: 0.6421 - val_loss: 0.7681 - val_accuracy: 0.6301
#
# Epoch 00099: val_loss did not improve from 0.70043
# Epoch 100/100
# 321/321 [==============================] - 1s 2ms/step - loss: 0.7354 - accuracy: 0.6629 - val_loss: 0.7165 - val_accuracy: 0.6699
#
# Epoch 00100: val_loss did not improve from 0.70043
# Training completed in time:  0:00:58.035531

# %%
train_accuracy=model.evaluate(X_train,y_train,verbose=0)
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(train_accuracy[1])
print(test_accuracy[1])
# Out:
# 0.6662764549255371
# 0.6699180603027344

# %%
#For normalized dataset
#0.654180109500885
#0.6531408429145813

#For non-normalized score
#0.6184763312339783
#0.6115332245826721


#For normalized dataset librosa settings
#0.6336942911148071
#0.6348029375076294

#0.6662764549255371
#0.6699180603027344

# %%
from kerastuner import RandomSearch
import keras_tuner
from kerastuner.engine.hyperparameters import HyperParameters
from tensorflow import keras

# %%
def build_model(hp):  
    model = keras.Sequential([
        keras.layers.Conv1D(
            filters=hp.Int('conv_1_filter', min_value=32, max_value=128, step=16),
            kernel_size=hp.Choice('conv_1_kernel', values = [2,5]),
            activation='relu',
            input_shape=X_train[1:]
        ),
        keras.layers.Conv1D(
            filters=hp.Int('conv_2_filter', min_value=32, max_value=64, step=16),
            kernel_size=hp.Choice('conv_2_kernel', values = [2,5]),
            activation='relu'
        ),
        
        keras.layers.Flatten(),
        keras.layers.Dense(
            units=hp.Int('dense_1_units', min_value=32, max_value=256, step=16),
            activation='relu'
        ),
        keras.layers.Dense(num_classes, activation='softmax')
    ])
    
    model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-2, 1e-3])),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
tuner_search=RandomSearch(build_model,
                          objective='val_accuracy',
                          max_trials=5,directory='output',project_name="Stress_clasification_plp")

# %%
tuner_search.search(X_train, y_train, epochs=3,validation_split=0.2)

# %%
model=tuner_search.get_best_models(num_models=1)[0]

# %%
model.summary()

# %%
model.fit(x_train_2D, y_train_2D, epochs=10, validation_split=0.1, initial_epoch=3)

# %%
train_accuracy=model.evaluate(X_train_cnn,Y_train_ann_cnn,verbose=0)
test_accuracy=model.evaluate(X_test_cnn,Y_test_ann_cnn,verbose=0)
print(train_accuracy[1])
print(test_accuracy[1])
